# %%
from matplotlib import pylab as plt
import numpy as np
import pandas as pd
import os
import sys
import seaborn as sns

# %%
corona_pandemie_points = pd.read_csv('data/shared-dataset/corona_pandemie_points.csv')
corona_warn_app_analyse_points = pd.read_csv('data/shared-dataset/corona_warn_app_analyse_points.csv')
reproduktionszahl_points = pd.read_csv('data/shared-dataset/reproduktionszahl_points.csv')
werbeindustrie_points = pd.read_csv('data/shared-dataset/werbeindustrie_points.csv')
dfs = {
    "corona_pandemie_points": corona_pandemie_points,
    "corona_warn_app_analyse_points": corona_warn_app_analyse_points,
    "reproduktionszahl_points": reproduktionszahl_points,
    "werbeindustrie_points": werbeindustrie_points
}

# %%
corona_pandemie_points
# Out:
#       id  total_points  rank  points_subtask_2  points_subtask_3  \
# 0   4c41            50     1                 2                 4
# 1   eac9            47     2                 2                 4
# 2   d28c            47     2                 2                 4
# 3   6b4e            42     4                 2                 4
# 4   1953            42     4                 2                 4
# 5   c926            40     6                 2                 4
# 6   8eaf            40     6                 2                 4
# 7   8d45            39     8                 2                 4
# 8   cb76            39     8                 2                 4
# 9   fe28            38    10                 2                 4
# 10  c938            38    10                 2                 4
# 11  3669            36    12                 2                 4
# 12  7cc7            35    13                 2                 4
# 13  88a6            35    13                 2                 4
# 14  ad47            35    13                 2                 4
# 15  4c2a            35    13                 2                 4
# 16  a044            34    17                 2                 4
# 17  b14b            34    17                 2                 3
# 18  44bd            34    17                 2                 4
# 19  b56b            34    17                 2                 4
# 20  8c43            33    21                 2                 4
# 21  23a6            32    22                 2                 4
# 22  2281            32    22                 2                 4
# 23  4ca2            31    24                 2                 2
# 24  baa4            31    24                 2                 4
# 25  63e1            30    26                 2                 4
# 26  066e            29    27                 2                 4
# 27  abd2            27    28                 2                 4
# 28  6f62            26    29                 2                 4
# 29  21de            25    30                 2                 4
# 30  6c5b            14    31                 2                 4
# 31  9eb2            11    32                 2                 2
# 32  fb4b             5    33                 0                 0
# 33  146f             2    34                 2                 0
# 34  8ac3             0    35                 0                 0
#
#     points_subtask_4  points_subtask_5.1  points_subtask_5.2  \
# 0                  6                   4                   6
# 1                  6                   4                   6
# 2                  6                   4                   3
# 3                  6                   4                   6
# 4                  6                   4                   6
# 5                  6                   4                   6
# 6                  6                   4                   6
# 7                  6                   4                   6
# 8                  5                   2                   2
# 9                  5                   4                   6
# 10                 6                   4                   6
# 11                 6                   4                   2
# 12                 6                   4                   2
# 13                 6                   4                   4
# 14                 6                   4                   3
# 15                 4                   1                   6
# 16                 6                   4                   4
# 17                 6                   4                   2
# 18                 6                   4                   0
# 19                 6                   4                   2
# 20                 6                   4                   6
# 21                 6                   4                   0
# 22                 6                   4                   2
# 23                 4                   1                   4
# 24                 6                   4                   2
# 25                 6                   4                   0
# 26                 6                   2                   3
# 27                 6                   1                   0
# 28                 4                   4                   1
# 29                 0                   2                   6
# 30                 2                   2                   2
# 31                 4                   0                   1
# 32                 0                   0                   0
# 33                 0                   0                   0
# 34                 0                   0                   0
#
#     points_subtask_6  points_subtask_7  points_subtask_8  points_subtask_9
# 0                 10                 4                 6                 8
# 1                 10                 4                 6                 5
# 2                 10                 4                 6                 8
# 3                 10                 4                 6                 0
# 4                  7                 4                 2                 7
# 5                  8                 4                 6                 0
# 6                  8                 4                 6                 0
# 7                 10                 4                 3                 0
# 8                  6                 4                 6                 8
# 9                  8                 3                 6                 0
# 10                10                 0                 6                 0
# 11                 8                 4                 6                 0
# 12                10                 4                 3                 0
# 13                 7                 2                 6                 0
# 14                 6                 4                 6                 0
# 15                 8                 4                 6                 0
# 16                 8                 0                 6                 0
# 17                 8                 3                 6                 0
# 18                 8                 4                 6                 0
# 19                 6                 4                 6                 0
# 20                 5                 4                 2                 0
# 21                 6                 4                 6                 0
# 22                10                 2                 2                 0
# 23                 9                 3                 6                 0
# 24                 7                 4                 2                 0
# 25                 8                 4                 2                 0
# 26                 4                 3                 5                 0
# 27                10                 2                 2                 0
# 28                 5                 0                 6                 0
# 29                 5                 0                 6                 0
# 30                 2                 0                 0                 0
# 31                 2                 0                 0                 0
# 32                 5                 0                 0                 0
# 33                 0                 0                 0                 0
# 34                 0                 0                 0                 0

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

for ax, (name, df) in zip(axes.flatten(), dfs.items()):
    sns.histplot(df['total_points'], kde=True, ax=ax)
    ax.set_title(name)

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

for ax, (name, df) in zip(axes.flatten(), dfs.items()):
    dfm = df.melt(['id', 'total_points', 'rank'], var_name='subtask',  value_name='points')
    sns.violinplot(dfm, x='points', hue='subtask', ax=ax)
    ax.set_title(name)

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

for ax, (name, df) in zip(axes.flatten(), dfs.items()):
    dfm = df.melt(['id', 'total_points', 'rank'], var_name='subtask',  value_name='points')
    sns.boxplot(dfm, x='points', y='subtask', width=.6, hue='subtask', ax=ax, whis=[0., 100.])
    sns.stripplot(dfm, x='points', y='subtask', hue='subtask', ax=ax, size=4)
    ax.xaxis.grid(True)
    ax.set(ylabel="")
    sns.despine(trim=True, left=True, ax=ax)
    ax.set_title(name)

plt.show()
