# %%
from matplotlib import pylab as plt
import numpy as np
import pandas as pd
import os
import sys
import seaborn as sns

# %% [markdown]
# ## Shared Dataset v1

# %%
corona_pandemie_points = pd.read_csv('data/shared-dataset/corona_pandemie_points.csv')
corona_warn_app_analyse_points = pd.read_csv('data/shared-dataset/corona_warn_app_analyse_points.csv')
reproduktionszahl_points = pd.read_csv('data/shared-dataset/reproduktionszahl_points.csv')
werbeindustrie_points = pd.read_csv('data/shared-dataset/werbeindustrie_points.csv')
dfs = {
    "corona_pandemie_points": corona_pandemie_points,
    "corona_warn_app_analyse_points": corona_warn_app_analyse_points,
    "reproduktionszahl_points": reproduktionszahl_points,
    "werbeindustrie_points": werbeindustrie_points
}

# %%
reproduktionszahl_points
# Out:
#       id  total_points  rank  points_subtask_2  points_subtask_3  \
# 0   4c41            28     1                 4                12
# 1   fe28            25     2                 4                12
# 2   44bd            23     3                 4                 9
# 3   eac9            22     4                 4                 9
# 4   3669            20     5                 4                 6
# 5   d28c            18     6                 4                 6
# 6   8d45            17     7                 4                 6
# 7   cb76            15     8                 4                 6
# 8   6b4e            12     9                 4                 3
# 9   b14b            12     9                 3                 3
# 10  baa4            12     9                 4                 3
# 11  2281            11    12                 4                 3
# 12  88a6            10    13                 4                 3
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

for ax, (name, df) in zip(axes.flatten(), dfs.items()):
    sns.histplot(df['total_points'], kde=True, ax=ax)
    ax.set_title(name)

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

for ax, (name, df) in zip(axes.flatten(), dfs.items()):
    dfm = df.melt(['id', 'total_points', 'rank'], var_name='subtask',  value_name='points')
    sns.violinplot(dfm, x='points', hue='subtask', ax=ax)
    ax.set_title(name)

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

for ax, (name, df) in zip(axes.flatten(), dfs.items()):
    dfm = df.melt(['id', 'total_points', 'rank'], var_name='subtask',  value_name='points')
    sns.boxplot(dfm, x='points', y='subtask', width=.6, hue='subtask', ax=ax, whis=[0., 100.])
    sns.stripplot(dfm, x='points', y='subtask', hue='subtask', ax=ax, size=4)
    ax.xaxis.grid(True)
    ax.set(ylabel="")
    sns.despine(trim=True, left=True, ax=ax)
    ax.set_title(name)

plt.show()

# %% [markdown]
# ## Shared Dataset v2

# %%
corona_pandemie_points = pd.read_csv('data/shared-dataset-v2/corona_pandemie_points.csv')
corona_warn_app_analyse_points = pd.read_csv('data/shared-dataset/corona_warn_app_analyse_points.csv')
reproduktionszahl_points = pd.read_csv('data/shared-dataset-v2/reproduktionszahl_points.csv')
werbeindustrie_points = pd.read_csv('data/shared-dataset-v2/werbeindustrie_points.csv')
dfs = {
    "corona_pandemie_points": corona_pandemie_points,
    "corona_warn_app_analyse_points": corona_warn_app_analyse_points,
    "reproduktionszahl_points": reproduktionszahl_points,
    "werbeindustrie_points": werbeindustrie_points
}

# %%
reproduktionszahl_points
# Out:
#       id  total_points  rank  points_subtask_2  points_subtask_3  \
# 0   9eb2             0    31                 0                 0
# 1   3669            20     5                 4                 6
# 2   6f62             4    22                 4                 0
# 3   066e             0    31                 0                 0
# 4   6b4e            12     9                 4                 3
# 5   1953             9    13                 4                 3
# 6   7cc7             7    17                 4                 0
# 7   88a6            10    13                 4                 3
# 8   23a6             7    17                 4                 0
# 9   fe28            25     2                 4                12
# 10  c938             4    22                 4                 0
# 11  a044             4    22                 4                 0
# 12  8ac3             0    31                 0                 0
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

for ax, (name, df) in zip(axes.flatten(), dfs.items()):
    sns.histplot(df['total_points'], kde=True, ax=ax)
    ax.set_title(name)

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

for ax, (name, df) in zip(axes.flatten(), dfs.items()):
    dfm = df.melt(['id', 'total_points', 'rank'], var_name='subtask',  value_name='points')
    sns.violinplot(dfm, x='points', hue='subtask', ax=ax)
    ax.set_title(name)

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

for ax, (name, df) in zip(axes.flatten(), dfs.items()):
    dfm = df.melt(['id', 'total_points', 'rank'], var_name='subtask',  value_name='points')
    sns.boxplot(dfm, x='points', y='subtask', width=.6, hue='subtask', ax=ax, whis=[0., 100.])
    sns.stripplot(dfm, x='points', y='subtask', hue='subtask', ax=ax, size=4)
    ax.xaxis.grid(True)
    ax.set(ylabel="")
    sns.despine(trim=True, left=True, ax=ax)
    ax.set_title(name)

plt.show()
