# %%
import pandas as pd
import re
import seaborn as sns
from matplotlib import pyplot as plt

# %%
expert_ranking = pd.read_csv('data/shared-dataset-v2/corona_warn_app_analyse_points.csv')
rankings = expert_ranking.loc[:, ['id', 'total_points']]
rankings.rename(columns={'total_points': 'expert'}, inplace=True)

# %% [markdown]
# ## Load Orders from Logfiles

# %%
files = {
    '001.2.r0': '001.2_llama3.3_azure.log',
    '001.2.r1': '001.2_llama3.3_azure.1.log',
    '001.2.r2': '001.2_llama3.3_azure.2.log',
    '001.2.r3': '001.2_llama3.3_azure.3.log',
    '007.2.r0': '007.2_llama3.3_azure.log'
}

files.update({
    '002.2': '002.2_deepseek_azure.log',
    '004.2': '004.2_azure_corona_warn_app.log',
    '008.2': '008.2_deepseek_azure.log',
    '011.2.r1': '011.2_reorder1.log',
    '011.2.r2': '011.2_reorder2.log',
    '011.2.r3': '011.2_reorder3.log',
    '011.2.r4': '011.2_reorder4.log',
})

files.update({
    '005.2': '005.2_markdown_with_tags.log',
    '006.2': '006.2_majority_vote.log',
    '009.2': '009.2_markdown.log',
    '010.2': '010.2_markdown_with_tags.log',
    '012.2': '012.2_option-labels.log',
    '013.2': '013.2_output_cells.log'
})

for experiment_id, file in files.items():
    with open(f'experiments/logs/{file}', 'r') as f:
        print(f'{file=}')
        for line in f.readlines():
            if re.match(r'.*Final order of notebooks:.*', line):
                print(line)
                matches = re.match(r'.*\[((\'[a-f0-9]+\'(, )?)+)\].*', line).group(1)
                ordering = [re.match(r"'([a-f0-9]+)'", m).group(1) for m in matches.split(', ')]

                rankings[experiment_id] = rankings['id'].map(lambda x: ordering.index(x))

rankings.set_index('id', inplace=True)
rankings.sort_values(by='expert', ascending=False)
# Out:
# file='001.2_llama3.3_azure.log'
# 2025-02-21 13:09:42,634 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '9eb2', '6c5b', '146f', '4ca2', '8d45', '21de', '6b4e', '8ac3', 'abd2', 'a044', '066e', '6f62', 'b56b', '4c2a', '8c43', 'c938', 'fe28', 'c926', 'eac9', '1953', '63e1', 'cb76', 'ad47', '44bd', 'baa4', '8eaf', '4c41', '3669', '23a6', '88a6', '2281', 'd28c', 'b14b', '7cc7']
#
# file='001.2_llama3.3_azure.1.log'
# 2025-02-20 21:47:47,732 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '9eb2', '6c5b', '146f', '8ac3', '4ca2', '8d45', 'abd2', '6b4e', 'a044', '21de', '066e', 'b56b', '6f62', '8c43', '4c2a', 'cb76', 'ad47', 'c938', '44bd', '1953', '63e1', '8eaf', '3669', 'b14b', 'baa4', 'c926', '23a6', 'eac9', 'fe28', '88a6', 'd28c', '4c41', '2281', '7cc7']
#
# file='001.2_llama3.3_azure.2.log'
# 2025-02-21 11:58:14,053 [INFO] Sorting finished. Final order of notebooks: ['146f', 'fb4b', '9eb2', '6c5b', '4ca2', '8ac3', '8d45', '6b4e', 'abd2', 'a044', '066e', '6f62', 'b56b', '4c2a', '8c43', '21de', 'fe28', 'ad47', '44bd', '63e1', '3669', 'cb76', '8eaf', '88a6', '7cc7', 'd28c', 'eac9', 'c926', '4c41', '1953', 'c938', 'baa4', '2281', '23a6', 'b14b']
#
# file='001.2_llama3.3_azure.3.log'
# 2025-02-21 12:38:07,046 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '9eb2', '6c5b', '146f', '4ca2', '8d45', '21de', '6b4e', '8ac3', 'abd2', 'a044', '066e', '6f62', 'b56b', '4c2a', '8c43', 'c938', 'fe28', 'c926', 'eac9', '1953', '63e1', 'cb76', 'ad47', '44bd', 'baa4', '8eaf', '4c41', '3669', '23a6', '88a6', '2281', 'd28c', 'b14b', '7cc7']
#
# file='007.2_llama3.3_azure.log'
# 2025-02-21 19:49:57,464 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '146f', '9eb2', '6c5b', '4ca2', '6b4e', '8ac3', '8d45', '4c2a', 'abd2', '066e', 'a044', '6f62', '8c43', '21de', 'b56b', 'b14b', 'baa4', 'd28c', '1953', '3669', '44bd', 'ad47', '63e1', 'c938', 'cb76', 'c926', 'fe28', '8eaf', '23a6', '4c41', 'eac9', '7cc7', '88a6', '2281']
#
# file='002.2_deepseek_azure.log'
# 2025-02-21 03:47:09,861 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '146f', '6c5b', '9eb2', 'a044', '8c43', '8d45', 'abd2', '6f62', '4ca2', '4c2a', 'b56b', '8ac3', '6b4e', 'ad47', '066e', '8eaf', '21de', 'cb76', '44bd', '23a6', '88a6', '1953', '63e1', 'c926', '3669', 'baa4', 'fe28', '2281', 'eac9', 'd28c', '4c41', 'c938', '7cc7', 'b14b']
#
# file='004.2_azure_corona_warn_app.log'
# 2025-02-20 19:56:45,063 [INFO] Sorting finished. Final order of notebooks: ['9eb2', '146f', '8d45', '6c5b', '066e', 'abd2', 'fb4b', '4ca2', '8c43', '21de', '4c2a', '8ac3', 'a044', 'b56b', '6b4e', 'ad47', '6f62', '63e1', '23a6', 'c938', 'fe28', '1953', 'b14b', '3669', '7cc7', 'c926', 'cb76', '8eaf', '44bd', '88a6', 'd28c', 'baa4', '2281', '4c41', 'eac9']
#
# file='008.2_deepseek_azure.log'
# 2025-02-22 01:26:39,268 [INFO] Sorting finished. Final order of notebooks: ['9eb2', '146f', 'fb4b', '6c5b', 'abd2', '8d45', 'a044', '8c43', '4c2a', 'b56b', '4ca2', '6b4e', '8ac3', '6f62', '066e', '8eaf', 'ad47', '21de', 'cb76', '88a6', 'baa4', '23a6', '63e1', '44bd', '3669', '1953', 'c926', 'fe28', 'c938', '7cc7', 'eac9', '2281', 'b14b', 'd28c', '4c41']
#
# file='011.2_reorder1.log'
# 2025-02-21 21:12:33,682 [INFO] Sorting finished. Final order of notebooks: ['146f', 'fb4b', '9eb2', '6c5b', '4ca2', '8ac3', '8d45', '6b4e', 'abd2', '066e', '21de', 'a044', '6f62', '4c2a', '8c43', 'b56b', '63e1', '4c41', 'fe28', 'c926', 'cb76', '8eaf', 'ad47', '44bd', '23a6', 'c938', '3669', '1953', '88a6', 'd28c', 'baa4', 'b14b', 'eac9', '2281', '7cc7']
#
# file='011.2_reorder2.log'
# 2025-02-21 21:24:36,023 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '9eb2', '6c5b', '146f', '8d45', '8ac3', '4ca2', '6b4e', '4c2a', 'abd2', '066e', 'a044', '8c43', '21de', '6f62', 'b56b', '88a6', 'd28c', '1953', '3669', '44bd', 'ad47', '63e1', 'baa4', 'c938', '8eaf', 'cb76', 'c926', 'fe28', '23a6', '4c41', 'eac9', '7cc7', '2281', 'b14b']
#
# file='011.2_reorder3.log'
# 2025-02-21 22:34:30,006 [INFO] Sorting finished. Final order of notebooks: ['146f', 'fb4b', '9eb2', '6c5b', '8ac3', '8d45', 'abd2', '066e', '4ca2', '21de', '6b4e', 'a044', '8c43', '6f62', '4c2a', 'b56b', '63e1', '4c41', 'fe28', 'cb76', '8eaf', 'ad47', 'c926', '44bd', 'c938', '3669', '1953', 'baa4', '23a6', '88a6', 'd28c', 'b14b', 'eac9', '2281', '7cc7']
#
# file='011.2_reorder4.log'
# 2025-02-26 13:52:28,016 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '9eb2', '6c5b', '146f', '8ac3', '4ca2', '8d45', 'abd2', '066e', '6b4e', 'a044', '21de', '6f62', '8c43', '4c2a', 'b56b', '3669', 'c938', '44bd', '1953', 'ad47', '63e1', '8eaf', '88a6', 'd28c', 'c926', 'baa4', 'cb76', 'fe28', '4c41', 'eac9', '23a6', '7cc7', '2281', 'b14b']
#
# file='005.2_markdown_with_tags.log'
# 2025-02-20 20:19:05,497 [INFO] Sorting finished. Final order of notebooks: ['9eb2', 'fb4b', '6c5b', '146f', '4ca2', 'abd2', '8d45', '8ac3', '4c2a', 'a044', '6b4e', '8c43', '21de', '066e', 'b56b', 'ad47', '6f62', 'fe28', '8eaf', '44bd', '88a6', '1953', 'cb76', '63e1', 'c926', 'b14b', '4c41', '3669', 'baa4', 'eac9', '23a6', '7cc7', 'c938', '2281', 'd28c']
#
# file='006.2_majority_vote.log'
# 2025-02-21 02:06:08,268 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '146f', '9eb2', '6c5b', 'abd2', '4c2a', '8ac3', '4ca2', '8d45', '6b4e', 'a044', '066e', '21de', 'fe28', '6f62', '8c43', 'b56b', 'c926', '44bd', 'ad47', 'baa4', '63e1', 'c938', '8eaf', 'eac9', '3669', '1953', 'd28c', '4c41', 'cb76', 'b14b', '88a6', '2281', '7cc7', '23a6']
#
# file='009.2_markdown.log'
# 2025-02-21 19:56:39,130 [INFO] Sorting finished. Final order of notebooks: ['9eb2', '146f', '8d45', 'fb4b', '6c5b', '066e', '4ca2', '4c2a', 'abd2', '8ac3', 'a044', 'b56b', '6b4e', '8c43', '21de', '6f62', 'b14b', 'd28c', '23a6', '1953', '3669', 'c938', '44bd', 'ad47', '63e1', 'baa4', '4c41', 'cb76', 'c926', 'fe28', '7cc7', '88a6', '2281', 'eac9', '8eaf']
#
# file='010.2_markdown_with_tags.log'
# 2025-02-21 20:03:08,213 [INFO] Sorting finished. Final order of notebooks: ['6c5b', '146f', '4ca2', '9eb2', 'fb4b', 'a044', '8ac3', '8d45', 'abd2', '4c2a', '21de', '066e', '6b4e', '6f62', '8c43', 'b56b', 'b14b', 'd28c', '23a6', '2281', '1953', '44bd', '3669', 'c938', 'ad47', '63e1', 'baa4', 'cb76', 'c926', 'fe28', '88a6', '4c41', 'eac9', '8eaf', '7cc7']
#
# file='012.2_option-labels.log'
# 2025-02-28 15:23:29,365 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '9eb2', '6c5b', '146f', '4ca2', '8ac3', '8d45', 'abd2', '21de', '4c2a', '066e', '6f62', 'b56b', '6b4e', 'a044', '8c43', '44bd', 'ad47', '63e1', '4c41', '3669', 'c938', 'cb76', 'fe28', '8eaf', '1953', 'b14b', 'baa4', 'd28c', 'c926', '23a6', 'eac9', '7cc7', '88a6', '2281']
#
# file='013.2_output_cells.log'
# 2025-03-04 14:36:07,799 [INFO] Sorting finished. Final order of notebooks: ['fb4b', '9eb2', '146f', 'a044', '8ac3', '6c5b', '21de', '4ca2', '8c43', '8d45', 'abd2', '066e', '6f62', '6b4e', '4c2a', 'b56b', 'b14b', 'd28c', '23a6', '1953', 'ad47', 'cb76', 'baa4', '44bd', '3669', 'c938', '4c41', 'eac9', '63e1', 'c926', '88a6', '8eaf', '2281', '7cc7', 'fe28']
#       expert  001.2.r0  001.2.r1  001.2.r2  001.2.r3  007.2.r0  002.2  004.2  \
# id
# 3669      20        28        23        20        28        20     25     23
# 1953      20        20        20        29        20        19     22     21
# 7cc7      20        34        34        24        34        32     33     24
# 63e1      20        21        21        19        21        23     23     17
# d28c      20        32        31        25        32        18     30     30
# fe28      20        17        29        16        17        27     27     20
# 2281      20        31        33        32        31        34     28     32
# eac9      20        19        28        26        19        31     29     34
# 4c41      20        27        32        28        27        30     31     33
# c926      19        18        26        27        18        26     24     25
# 44bd      19        24        19        18        24        21     19     28
# c938      19        16        18        30        16        24     32     19
# 88a6      19        30        30        23        30        33     21     29
# b14b      18        33        24        34        33        16     34     22
# baa4      17        25        25        31        25        17     26     31
# ad47      15        23        17        17        23        22     14     15
# 23a6      15        29        27        33        29        29     20     18
# 6b4e      14         7         8         7         7         5     13     14
# 066e      13        11        11        10        11        10     15      4
# cb76      13        22        16        21        22        25     18     26
# 4ca2      10         4         5         4         4         4      9      7
# 4c2a       9        14        15        13        14         8     10     10
# 8d45       9         5         6         6         5         7      6      2
# abd2       9         9         7         8         9         9      7      5
# 6f62       8        12        13        11        12        12      8     16
# 8eaf       7        26        22        22        26        28     16     27
# 21de       7         6        10        15         6        14     17      9
# a044       6        10         9         9        10        11      4     12
# 8c43       6        15        14        14        15        13      5      8
# b56b       6        13        12        12        13        15     11     13
# 8ac3       4         8         4         5         8         6     12     11
# 6c5b       2         2         2         3         2         3      2      3
# 9eb2       0         1         1         2         1         2      3      0
# fb4b       0         0         0         1         0         0      0      6
# 146f       0         3         3         0         3         1      1      1
#
#       008.2  011.2.r1  011.2.r2  011.2.r3  011.2.r4  005.2  006.2  009.2  \
# id
# 3669     24        26        19        25        16     27     25     20
# 1953     25        27        18        26        19     21     26     19
# 7cc7     29        34        32        34        32     31     33     30
# 63e1     22        16        22        16        21     23     21     24
# d28c     33        29        17        30        24     34     27     17
# fe28     27        18        28        18        28     17     13     29
# 2281     31        33        33        33        33     33     32     32
# eac9     30        32        31        32        30     29     24     33
# 4c41     34        17        30        17        29     26     28     26
# c926     26        19        27        22        25     24     17     28
# 44bd     23        23        20        23        18     19     18     22
# c938     28        25        24        24        17     32     22     21
# 88a6     19        28        16        29        23     20     31     31
# b14b     32        31        34        31        34     25     30     16
# baa4     20        30        23        27        26     28     20     25
# ad47     16        22        21        21        20     15     19     23
# 23a6     21        24        29        28        31     30     34     18
# 6b4e     11         7         7        10         9     10      9     12
# 066e     14         9        10         7         8     13     11      5
# cb76     18        20        26        19        27     22     29     27
# 4ca2     10         4         6         8         5      4      7      6
# 4c2a      8        13         8        14        14      8      5      7
# 8d45      5         6         4         5         6      6      8      2
# abd2      4         8         9         6         7      5      4      8
# 6f62     13        12        14        13        12     16     14     15
# 8eaf     15        21        25        20        22     18     23     34
# 21de     17        10        13         9        11     12     12     14
# a044      6        11        11        11        10      9     10     10
# 8c43      7        14        12        12        13     11     15     13
# b56b      9        15        15        15        15     14     16     11
# 8ac3     12         5         5         4         4      7      6      9
# 6c5b      3         3         2         3         2      2      3      4
# 9eb2      0         2         1         2         1      0      2      0
# fb4b      2         1         0         1         0      1      0      3
# 146f      1         0         3         0         3      3      1      1
#
#       010.2  012.2  013.2
# id
# 3669     22     20     24
# 1953     20     25     19
# 7cc7     34     32     33
# 63e1     25     18     28
# d28c     17     28     17
# fe28     29     23     34
# 2281     19     34     32
# eac9     32     31     27
# 4c41     31     19     26
# c926     28     29     29
# 44bd     21     16     23
# c938     23     21     25
# 88a6     30     33     30
# b14b     16     26     16
# baa4     26     27     22
# ad47     24     17     20
# 23a6     18     30     18
# 6b4e     12     13     13
# 066e     11     10     11
# cb76     27     22     21
# 4ca2      2      4      7
# 4c2a      9      9     14
# 8d45      7      6      9
# abd2      8      7     10
# 6f62     13     11     12
# 8eaf     33     24     31
# 21de     10      8      6
# a044      5     14      3
# 8c43     14     15      8
# b56b     15     12     15
# 8ac3      6      5      4
# 6c5b      0      2      5
# 9eb2      3      1      1
# fb4b      4      0      0
# 146f      1      3      2

# %%
import numpy as np
def ndcg_score(relevances: np.ndarray, scores: np.ndarray) -> float:
    """
    Calculate the normalized Discounted Cumulative Gain (nDCG).
    
    Parameters:
        relevances (np.ndarray): True relevance scores (1D array).
        scores (np.ndarray): Predicted scores (1D array) used for ranking.
    
    Returns:
        float: The nDCG value.
    """
    if relevances.shape != scores.shape:
        raise ValueError("Both input arrays must have the same shape.")
    
    # Order the indices by descending predicted scores
    order = np.argsort(scores)[::-1]
    sorted_relevances = relevances[order]
    
    # Calculate discounts: positions start at 1 (hence np.arange starts at 2)
    discounts = np.log2(np.arange(2, len(sorted_relevances) + 2))
    
    # Compute Discounted Cumulative Gain (DCG)
    dcg = np.sum((2 ** sorted_relevances - 1) / discounts)
    
    # Compute Ideal DCG (IDCG) using true relevances sorted in descending order
    ideal_order = np.argsort(relevances)[::-1]
    ideal_relevances = relevances[ideal_order]
    ideal_dcg = np.sum((2 ** ideal_relevances - 1) / discounts)
    
    # If the ideal DCG is 0, return 0 to avoid division by zero
    if ideal_dcg == 0:
        return 0.0
    
    return dcg / ideal_dcg

# %%
plt.figure(figsize=[12, 12])
sns.heatmap(rankings.corr(method='kendall'), annot=True, fmt=".2f", cmap='flare')
plt.show()

# %%
plt.figure(figsize=[12, 12])
sns.heatmap(rankings.corr(method=ndcg_score), annot=True, fmt=".2f", cmap='flare')
plt.show()

# %%
df = rankings.corr(method='kendall').loc[:, ['expert']].join(
    rankings.corr(method=ndcg_score).loc[:, ['expert']], rsuffix='_ndcg'
)
df.rename({
    'expert': 'kendall', 
    'expert_ndcg': 'nDCG'
})
df
# Out:
#             expert  expert_ndcg
# expert    1.000000     1.000000
# 001.2.r0  0.569306     0.884584
# 001.2.r1  0.692684     0.963588
# 001.2.r2  0.551680     0.757471
# 001.2.r3  0.569306     0.884584
# 007.2.r0  0.572831     0.911077
# 002.2     0.717360     0.858252
# 004.2     0.586931     0.926650
# 008.2     0.742036     0.955573
# 011.2.r1  0.601032     0.926071
# 011.2.r2  0.565780     0.835422
# 011.2.r3  0.629232     0.928554
# 011.2.r4  0.579881     0.823122
# 005.2     0.639808     0.928976
# 006.2     0.569306     0.789177
# 009.2     0.565780     0.800980
# 010.2     0.572831     0.875797
# 012.2     0.593981     0.901225
# 013.2     0.689159     0.935303

# %% [markdown]
# ## Reordering (Exp. 011)

# %%
expert_ranking = pd.read_csv('data/shared-dataset-v2/werbeindustrie_points.csv')
rankings = expert_ranking.loc[:, ['id', 'total_points']]
rankings.rename(columns={'total_points': 'expert'}, inplace=True)

files = {
    '011.4.r1': '011.4_reorder1.log',
    '011.4.r2': '011.4_reorder2.log',
    '011.4.r3': '011.4_reorder3.log',
    '011.4.r4': '011.4_reorder4.log',
}

for experiment_id, file in files.items():
    with open(f'experiments/logs/{file}', 'r') as f:
        print(f'{file=}')
        for line in f.readlines():
            if re.match(r'.*Final order of notebooks:.*', line):
                print(line)
                matches = re.match(r'.*\[((\'[a-f0-9]+\'(, )?)+)\].*', line).group(1)
                ordering = [re.match(r"'([a-f0-9]+)'", m).group(1) for m in matches.split(', ')]

                rankings[experiment_id] = rankings['id'].map(lambda x: ordering.index(x))

rankings.set_index('id', inplace=True)
print(rankings.corr(method='kendall'))

plt.figure(figsize=[8, 6])
sns.heatmap(rankings.corr(method='kendall'), annot=True, fmt=".3f")
plt.show()
# Out:
# file='011.4_reorder1.log'
# 2025-02-21 21:15:32,233 [INFO] Sorting finished. Final order of notebooks: ['066e', 'fb4b', '9eb2', '6c5b', '8ac3', 'abd2', '63e1', 'ad47', '1953', '4ca2', '4c2a', '44bd', '21de', '6f62', '2281', 'fe28', '146f', '3669', '8d45', '88a6', 'b56b', 'c938', '7cc7', 'd28c', 'baa4', '6b4e', 'c926', 'a044', 'b14b', 'cb76', '8eaf', '8c43', 'eac9', '4c41', '23a6']
#
# file='011.4_reorder2.log'
# 2025-02-21 21:27:45,589 [INFO] Sorting finished. Final order of notebooks: ['9eb2', 'fb4b', '066e', '6c5b', '8ac3', 'abd2', '4c2a', 'ad47', '63e1', '44bd', '21de', '1953', '4ca2', '2281', '3669', '6f62', 'b56b', '7cc7', 'fe28', '146f', 'c938', 'a044', 'b14b', '88a6', 'd28c', 'baa4', '6b4e', '8d45', '8c43', 'c926', 'cb76', '23a6', 'eac9', '8eaf', '4c41']
#
# file='011.4_reorder3.log'
# 2025-02-21 22:37:12,257 [INFO] Sorting finished. Final order of notebooks: ['066e', 'fb4b', '9eb2', '6c5b', 'abd2', '8ac3', '63e1', '4c2a', 'ad47', '1953', '4ca2', '44bd', '21de', '3669', '2281', '6f62', 'fe28', '146f', '8d45', '88a6', 'b56b', 'c938', '7cc7', 'd28c', 'baa4', '6b4e', '8c43', 'c926', 'a044', 'b14b', 'cb76', 'eac9', '8eaf', '4c41', '23a6']
#
# file='011.4_reorder4.log'
# 2025-02-26 13:55:09,778 [INFO] Sorting finished. Final order of notebooks: ['066e', 'fb4b', '9eb2', '6c5b', 'abd2', '63e1', '21de', '2281', '8ac3', '4c2a', '44bd', '4ca2', 'ad47', '3669', '1953', '6f62', 'b56b', '7cc7', 'fe28', '146f', 'c938', 'a044', 'b14b', '88a6', 'd28c', '6b4e', '8d45', '8c43', 'baa4', 'c926', 'cb76', '23a6', 'eac9', '4c41', '8eaf']
#
#             expert  011.4.r1  011.4.r2  011.4.r3  011.4.r4
# expert    1.000000  0.460515  0.414815  0.449968  0.383176
# 011.4.r1  0.460515  1.000000  0.831933  0.949580  0.788235
# 011.4.r2  0.414815  0.831933  1.000000  0.855462  0.915966
# 011.4.r3  0.449968  0.949580  0.855462  1.000000  0.818487
# 011.4.r4  0.383176  0.788235  0.915966  0.818487  1.000000

# %% [markdown]
# ## Position Bias

# %%
comparisons = []
files = [
    '007.2_llama3.3_azure.log', '008.2_deepseek_azure.log', '009.2_markdown.log', '010.2_markdown_with_tags.log', '011.2_reorder1.log', '011.2_reorder2.log', '011.2_reorder3.log', '011.2_reorder4.log', 'unknown_randomization/001.2_llama3.3_azure.1.log', 'unknown_randomization/001.2_llama3.3_azure.2.log', 'unknown_randomization/001.2_llama3.3_azure.3.log', 'unknown_randomization/001.2_llama3.3_azure.log', 'unknown_randomization/002.2_deepseek_azure.log', 'unknown_randomization/004.2_azure_corona_warn_app.log', 'unknown_randomization/005.2_markdown_with_tags.log', 'unknown_randomization/006.2_majority_vote.log'
]

for file in files:
    with open(f'experiments/logs/{file}', 'r') as f:
        comparisons.extend([f.strip()[-11:] for f in f.readlines() if re.match(r'.*[a-f0-9]{4} [<>] [a-f0-9]{4}$', f)])

print(len(comparisons))
# Out:
# 3167

# %%
def check_comparison(c: str) -> bool:
    a, cmp, b = c.split(' ')
    if cmp == '<':
        return expert_ranking.loc[expert_ranking['id'] == a, 'total_points'].values[0] <= expert_ranking.loc[expert_ranking['id'] == b, 'total_points'].values[0]
    else:
        return expert_ranking.loc[expert_ranking['id'] == a, 'total_points'].values[0] >= expert_ranking.loc[expert_ranking['id'] == b, 'total_points'].values[0]

def comparision_points_diff(c: str) -> int:
    a, cmp, b = c.split(' ')
    return expert_ranking.loc[expert_ranking['id'] == a, 'total_points'].values[0] - expert_ranking.loc[expert_ranking['id'] == b, 'total_points'].values[0]

problematic_notebooks: dict = {}
point_diffs: dict = {}

for c in comparisons:
    if check_comparison(c):
        print('Correct', end='')
        pass
    else:
        print('Wrong  ', end='')
        a, cmp, b = c.split(' ')
        problematic_notebooks[a] = problematic_notebooks.get(a, 0) + 1
        problematic_notebooks[b] = problematic_notebooks.get(b, 0) + 1

        point_diffs[a] = point_diffs.get(a, 0) - comparision_points_diff(c)
        point_diffs[b] = point_diffs.get(b, 0) + comparision_points_diff(c)

    print(f' {c} by {comparision_points_diff(c)}')
# Out:
# Correct 146f < fe28 by -20
# Correct fe28 > c926 by 1
# Wrong   8d45 < 8eaf by 2
# Correct 8eaf < 88a6 by -12
# Wrong   6f62 > 6b4e by -6
# Correct 6f62 < b14b by -10
# Wrong   23a6 > d28c by -5
# Correct 23a6 > 21de by 8
# Correct b56b > 6c5b by 4
# Wrong   b56b > 4c2a by -3
# Correct 1953 < 2281 by 0
# Correct 2281 > 066e by 7
# Correct c938 > 8ac3 by 15
# Wrong   c938 > 3669 by -1
# Correct 9eb2 < eac9 by -20
# Correct eac9 > 4c41 by 0
# Wrong   cb76 > ad47 by -2
# Wrong   cb76 > 63e1 by -7
# Wrong   88a6 > fe28 by -1
# Wrong   8d45 < 8eaf by 2
# Correct 8eaf > 8c43 by 1
# Wrong   23a6 > b14b by -3
# Correct 21de < d28c by -13
# Correct d28c > baa4 by 3
# Correct 2281 > b56b by 14
# Correct 1953 > 066e by 7
# Correct 1953 > abd2 by 11
# Correct eac9 > c938 by 1
# Correct 9eb2 < 4c41 by -20
# Correct 4c41 > 44bd by 1
# Correct 88a6 > cb76 by 6
# Wrong   8eaf > fe28 by -13
# Wrong   8d45 < 8c43 by 3
# Correct 8c43 < 7cc7 by -14
# Correct 8eaf < 7cc7 by -13
# Wrong   88a6 > 7cc7 by -1
# Correct 2281 > 23a6 by 5
# Correct 1953 > b56b by 14
# Correct abd2 < 066e by -4
# Correct 066e > 4ca2 by 3
# Wrong   88a6 > eac9 by -1
# Correct 7cc7 > cb76 by 7
# Wrong   8eaf > fe28 by -13
# Wrong   8d45 < 8c43 by 3
# Correct 8c43 > a044 by 0
# Correct 88a6 < 2281 by -1
# Wrong   1953 < 23a6 by 5
# Correct d28c > b14b by 2
# Correct 21de < baa4 by -10
# Correct baa4 > fb4b by 17
# Correct 88a6 > 23a6 by 4
# Correct 7cc7 > eac9 by 0
# Wrong   8eaf > cb76 by -6
# Correct 8c43 < fe28 by -14
# Correct 146f < c926 by -19
# Correct fe28 > c926 by 1
# Correct 7cc7 > 23a6 by 5
# Correct 8eaf < eac9 by -13
# Correct 4c41 > c938 by 1
# Correct 9eb2 < 44bd by -19
# Correct 44bd > 146f by 19
# Correct eac9 > 23a6 by 5
# Correct 8eaf < 4c41 by -13
# Correct 44bd < c938 by 0
# Correct 3669 > 8ac3 by 16
# Correct 3669 > a044 by 14
# Correct 4c41 > 23a6 by 5
# Wrong   8eaf > c938 by -12
# Correct fe28 > cb76 by 7
# Correct 8c43 < c926 by -13
# Correct c926 > 8d45 by 10
# Correct 8eaf < 23a6 by -8
# Correct 1953 > d28c by 0
# Wrong   066e < b56b by 7
# Correct 4c2a > 6c5b by 7
# Wrong   4c2a > 6b4e by -5
# Wrong   8eaf > 1953 by -13
# Correct fe28 > c938 by 1
# Correct c926 > cb76 by 6
# Wrong   8c43 > 8d45 by -3
# Wrong   8c43 > 6f62 by -2
# Correct fe28 > 1953 by 0
# Correct c926 > c938 by 0
# Correct 8c43 < cb76 by -7
# Correct 63e1 > ad47 by 5
# Correct 63e1 > fb4b by 20
# Wrong   c926 > 1953 by -1
# Wrong   cb76 > c938 by -6
# Correct 8c43 < 63e1 by -14
# Correct fb4b < ad47 by -15
# Correct ad47 > 21de by 8
# Wrong   cb76 > 1953 by -7
# Wrong   63e1 < c938 by 1
# Wrong   44bd > 3669 by -1
# Correct 9eb2 > 146f by 0
# Correct 9eb2 < 6c5b by -2
# Correct 44bd > 6c5b by 17
# Wrong   c938 > 1953 by -1
# Correct 63e1 > 44bd by 1
# Correct 8c43 < ad47 by -9
# Correct fb4b < 21de by -7
# Wrong   21de > 6b4e by -7
# Correct 63e1 > 1953 by 0
# Wrong   ad47 > 44bd by -4
# Correct 8c43 < 21de by -1
# Correct fb4b < 6b4e by -14
# Correct 6b4e > 4ca2 by 4
# Wrong   ad47 > 1953 by -5
# Correct 21de < 44bd by -12
# Correct 6c5b < 3669 by -18
# Correct a044 > 8ac3 by 2
# Wrong   a044 > abd2 by -3
# Wrong   44bd > 1953 by -1
# Correct 21de < 3669 by -13
# Correct 6c5b < a044 by -4
# Correct abd2 > 8ac3 by 5
# Correct 3669 > 1953 by 0
# Correct 21de > a044 by 1
# Wrong   8c43 > 6b4e by -8
# Wrong   6f62 > 8d45 by -1
# Correct 6f62 > 8ac3 by 4
# Correct 21de < 1953 by -13
# Correct b56b < d28c by -14
# Wrong   baa4 > b14b by -1
# Correct baa4 > 146f by 17
# Correct 21de < d28c by -13
# Correct b56b < baa4 by -11
# Correct 146f < b14b by -18
# Correct b14b > 9eb2 by 18
# Correct 21de < baa4 by -10
# Correct b56b < b14b by -12
# Correct 146f > 9eb2 by 0
# Correct 146f < 4ca2 by -10
# Correct b14b > 4ca2 by 8
# Correct 21de < b14b by -11
# Wrong   b56b > 4ca2 by -4
# Correct 066e > 4c2a by 4
# Correct 066e > fb4b by 13
# Wrong   21de < b56b by 1
# Correct 066e > 4ca2 by 3
# Correct fb4b < 4c2a by -9
# Correct 4c2a > 8d45 by 0
# Wrong   21de > 066e by -6
# Correct 8c43 > a044 by 0
# Wrong   6f62 > 6b4e by -6
# Correct 6f62 > 8ac3 by 4
# Wrong   8c43 > 066e by -7
# Correct 6f62 > a044 by 2
# Wrong   8ac3 > 6b4e by -10
# Correct 8ac3 > 9eb2 by 4
# Wrong   6f62 > 066e by -5
# Correct 8ac3 < a044 by -2
# Correct 6c5b < abd2 by -7
# Correct abd2 > 146f by 9
# Wrong   a044 > 066e by -7
# Correct 8ac3 < abd2 by -5
# Correct 6c5b > 146f by 2
# Correct 6c5b < 8d45 by -7
# Correct abd2 > 8d45 by 0
# Correct abd2 < 066e by -4
# Wrong   4c2a > 4ca2 by -1
# Correct 4c2a > fb4b by 9
# Correct abd2 > 4c2a by 0
# Correct 8ac3 < 8d45 by -5
# Correct 6c5b > 146f by 2
# Correct 8d45 < 4c2a by 0
# Correct fb4b < 4ca2 by -10
# Correct 4ca2 > 146f by 10
# Wrong   8d45 > 4ca2 by -1
# Correct 8ac3 > 6c5b by 2
# Correct 9eb2 < 6b4e by -14
# Wrong   8ac3 > 6b4e by -10
# Wrong   8ac3 > 4ca2 by -6
# Correct 6b4e > 6c5b by 12
# Correct 6b4e > 9eb2 by 14
# Correct 6b4e > 4ca2 by 4
# Correct 9eb2 < 6c5b by -2
# Correct 6c5b > 146f by 2
# Correct 6c5b < 4ca2 by -8
# Correct 4ca2 > fb4b by 10
# Correct 6c5b > fb4b by 2
# Correct 9eb2 > 146f by 0
# Correct 9eb2 > fb4b by 0
# Correct 9eb2 > 146f by 0
# Correct 146f > fb4b by 0
# Correct 146f < fe28 by -20
# Correct fe28 > c926 by 1
# Wrong   8d45 < 8eaf by 2
# Correct 8eaf < 88a6 by -12
# Wrong   6f62 > 6b4e by -6
# Correct 6f62 < b14b by -10
# Correct 23a6 < d28c by -5
# Correct d28c > 21de by 13
# Correct b56b > 6c5b by 4
# Wrong   b56b > 4c2a by -3
# Correct 1953 < 2281 by 0
# Correct 2281 > 066e by 7
# Correct c938 > 8ac3 by 15
# Wrong   c938 > 3669 by -1
# Correct 9eb2 < eac9 by -20
# Correct eac9 < 4c41 by 0
# Wrong   cb76 > ad47 by -2
# Correct cb76 < 63e1 by -7
# Correct 88a6 < fe28 by -1
# Correct 146f < c926 by -19
# Correct c926 > 8c43 by 13
# Correct d28c > b14b by 2
# Correct 23a6 > 21de by 8
# Wrong   23a6 > baa4 by -2
# Correct 2281 > b56b by 14
# Correct 1953 > 066e by 7
# Correct 1953 > abd2 by 11
# Correct 4c41 > c938 by 1
# Correct 9eb2 < eac9 by -20
# Correct eac9 > 44bd by 1
# Correct fe28 > 63e1 by 0
# Correct 88a6 < c926 by 0
# Correct 146f < 8c43 by -6
# Correct 8c43 < 7cc7 by -14
# Correct c926 < 7cc7 by -1
# Correct fe28 < 7cc7 by 0
# Correct 2281 < d28c by 0
# Correct 23a6 < b14b by -3
# Wrong   6f62 > 6b4e by -6
# Correct 6f62 < 4ca2 by -2
# Correct b14b > 4ca2 by 8
# Correct 7cc7 < 4c41 by 0
# Correct eac9 > c938 by 1
# Correct 9eb2 < 44bd by -19
# Correct 44bd > a044 by 13
# Correct 4c41 > d28c by 0
# Correct 7cc7 < eac9 by 0
# Correct 44bd < c938 by 0
# Correct 3669 > 8ac3 by 16
# Correct 3669 > fb4b by 20
# Correct eac9 < d28c by 0
# Wrong   2281 < b14b by 2
# Correct 23a6 > 4ca2 by 5
# Correct baa4 > 21de by 10
# Correct baa4 > 8c43 by 11
# Wrong   eac9 < b14b by 2
# Correct 2281 > 23a6 by 5
# Correct 1953 > b56b by 14
# Correct abd2 < 066e by -4
# Correct 066e > 146f by 13
# Correct eac9 < 2281 by 0
# Correct 1953 > 23a6 by 5
# Correct 066e > b56b by 7
# Correct abd2 > 146f by 9
# Wrong   abd2 < 8eaf by 2
# Wrong   066e < 8eaf by 6
# Correct 1953 > 8eaf by 13
# Correct eac9 > 1953 by 0
# Correct 7cc7 > c938 by 1
# Correct fe28 > 63e1 by 0
# Correct 88a6 < c926 by 0
# Correct c926 > 8d45 by 10
# Correct 7cc7 > 1953 by 0
# Wrong   fe28 < c938 by 1
# Correct 44bd < 3669 by -1
# Correct fb4b < 8ac3 by -4
# Wrong   8ac3 > 6b4e by -10
# Wrong   c938 > 1953 by -1
# Correct fe28 > 3669 by 0
# Wrong   c926 > 63e1 by -1
# Correct 88a6 > 8d45 by 10
# Correct 88a6 > 6f62 by 11
# Correct fe28 > 1953 by 0
# Wrong   c926 > 3669 by -1
# Correct 88a6 < 63e1 by -1
# Wrong   cb76 > ad47 by -2
# Correct cb76 > 21de by 6
# Wrong   c926 > 1953 by -1
# Correct 63e1 < 3669 by 0
# Correct 44bd > 8ac3 by 15
# Correct 9eb2 < a044 by -6
# Correct a044 < 8c43 by 0
# Correct 44bd > 8c43 by 13
# Correct 3669 < 1953 by 0
# Correct 8eaf < 23a6 by -8
# Correct baa4 > 4ca2 by 7
# Correct baa4 > 6c5b by 15
# Correct 3669 > 23a6 by 5
# Wrong   63e1 < 44bd by 1
# Wrong   8c43 < 8ac3 by 2
# Correct fb4b < 6b4e by -14
# Correct 6b4e > 4c2a by 5
# Correct 44bd > 23a6 by 4
# Correct 63e1 > 8ac3 by 16
# Correct 88a6 > cb76 by 6
# Wrong   6f62 > 8d45 by -1
# Correct 6f62 > 146f by 8
# Correct 63e1 > 23a6 by 5
# Correct 88a6 > 8ac3 by 15
# Correct 6f62 < cb76 by -5
# Wrong   21de > ad47 by -8
# Wrong   21de > abd2 by -2
# Wrong   88a6 < 23a6 by 4
# Correct 8eaf < baa4 by -10
# Correct 6c5b < 4ca2 by -8
# Wrong   4ca2 < 4c2a by 1
# Correct baa4 > 4c2a by 8
# Wrong   88a6 < baa4 by 2
# Wrong   8eaf > 4c2a by -2
# Correct 066e > b56b by 7
# Correct 066e > fb4b by 13
# Correct 88a6 > 8eaf by 12
# Correct cb76 > 8ac3 by 9
# Wrong   6f62 < 21de by 1
# Correct abd2 < ad47 by -6
# Correct ad47 > a044 by 9
# Correct cb76 > 8eaf by 6
# Correct 21de > 8ac3 by 3
# Correct 6f62 < ad47 by -7
# Correct abd2 > a044 by 3
# Correct abd2 > 9eb2 by 9
# Correct 21de > 8eaf by 0
# Correct ad47 > 8ac3 by 11
# Wrong   6f62 > abd2 by -1
# Correct 146f < 8d45 by -9
# Wrong   8d45 < a044 by 3
# Correct 6f62 > a044 by 2
# Correct ad47 > 8eaf by 8
# Correct 6f62 > 8ac3 by 4
# Wrong   a044 > abd2 by -3
# Correct 146f < 8d45 by -9
# Correct 8d45 > 9eb2 by 9
# Wrong   6f62 < 8eaf by 1
# Correct 066e > 4c2a by 4
# Correct fb4b < b56b by -6
# Correct b56b > 9eb2 by 6
# Correct 6f62 < 066e by -5
# Wrong   b56b > 4c2a by -3
# Correct fb4b < 9eb2 by 0
# Correct 9eb2 > 146f by 0
# Correct 6f62 > b56b by 2
# Wrong   a044 < 8ac3 by 2
# Correct 8c43 < 6b4e by -8
# Correct 6b4e > 4ca2 by 4
# Wrong   8ac3 > b56b by -2
# Correct a044 < 6b4e by -8
# Correct 8c43 < 4ca2 by -4
# Correct 4ca2 > 6c5b by 8
# Correct 6b4e > b56b by 8
# Correct a044 < 4ca2 by -4
# Correct 8c43 > 6c5b by 4
# Correct 8c43 > 146f by 6
# Correct 4ca2 > b56b by 4
# Correct a044 < 8c43 by 0
# Wrong   146f > 6c5b by -2
# Correct 146f > fb4b by 0
# Correct 8c43 < b56b by 0
# Correct 9eb2 < 4c2a by -9
# Correct 4c2a > 6c5b by 7
# Correct 8c43 < 4c2a by -3
# Wrong   9eb2 > 6c5b by -2
# Correct 9eb2 > fb4b by 0
# Correct 8c43 > 9eb2 by 6
# Correct a044 > 146f by 6
# Correct 8d45 > abd2 by 0
# Correct a044 > 9eb2 by 6
# Correct 8d45 > 146f by 9
# Correct 8d45 > abd2 by 0
# Correct 8d45 > 9eb2 by 9
# Correct abd2 > 146f by 9
# Correct abd2 > 6c5b by 7
# Correct abd2 > 9eb2 by 9
# Correct 6c5b > 146f by 2
# Correct 6c5b > fb4b by 2
# Correct 6c5b > 9eb2 by 2
# Correct fb4b > 146f by 0
# Correct fb4b > 9eb2 by 0
# Correct fb4b > 146f by 0
# Correct 146f > 9eb2 by 0
# Correct 146f < fe28 by -20
# Correct fe28 > c926 by 1
# Wrong   8d45 < 8eaf by 2
# Wrong   8eaf > 88a6 by -12
# Wrong   6f62 > 6b4e by -6
# Correct 6f62 < b14b by -10
# Wrong   23a6 > d28c by -5
# Correct 23a6 > 21de by 8
# Correct b56b > 6c5b by 4
# Wrong   b56b > 4c2a by -3
# Correct 1953 < 2281 by 0
# Correct 2281 > 066e by 7
# Correct c938 > 8ac3 by 15
# Wrong   c938 > 3669 by -1
# Correct 9eb2 < eac9 by -20
# Correct eac9 > 4c41 by 0
# Wrong   cb76 > ad47 by -2
# Wrong   cb76 > 63e1 by -7
# Wrong   8eaf > fe28 by -13
# Correct 8d45 < 88a6 by -10
# Correct 88a6 > 8c43 by 13
# Wrong   23a6 > b14b by -3
# Correct 21de < d28c by -13
# Correct d28c > baa4 by 3
# Correct 2281 > b56b by 14
# Correct 1953 > 066e by 7
# Correct 1953 > abd2 by 11
# Correct eac9 > c938 by 1
# Correct 9eb2 < 4c41 by -20
# Correct 4c41 > 44bd by 1
# Wrong   8eaf > cb76 by -6
# Wrong   88a6 > fe28 by -1
# Wrong   8d45 < 8c43 by 3
# Correct 8c43 < 7cc7 by -14
# Wrong   88a6 > 7cc7 by -1
# Correct 2281 > 23a6 by 5
# Correct 1953 > b56b by 14
# Wrong   abd2 > 066e by -4
# Wrong   abd2 > 4ca2 by -1
# Wrong   8eaf > eac9 by -13
# Correct 88a6 > cb76 by 6
# Correct 7cc7 > fe28 by 0
# Wrong   8d45 < 8c43 by 3
# Correct 8c43 > a044 by 0
# Wrong   8eaf > 2281 by -13
# Correct 88a6 < eac9 by -1
# Correct 4c41 > c938 by 1
# Correct 9eb2 < 44bd by -19
# Correct 44bd > fb4b by 19
# Correct eac9 > 2281 by 0
# Wrong   88a6 > 4c41 by -1
# Correct 7cc7 > cb76 by 7
# Correct 8c43 < fe28 by -14
# Correct 146f < c926 by -19
# Correct fe28 > c926 by 1
# Correct 88a6 < 2281 by -1
# Correct 1953 > 23a6 by 5
# Wrong   abd2 < b56b by 3
# Correct 4c2a > 6c5b by 7
# Correct 4c2a > 146f by 9
# Wrong   88a6 > 1953 by -1
# Correct 7cc7 > 4c41 by 0
# Correct fe28 > cb76 by 7
# Correct 8c43 < c926 by -13
# Correct c926 > a044 by 13
# Correct 7cc7 > 1953 by 0
# Correct fe28 > 4c41 by 0
# Correct c926 > cb76 by 6
# Correct 8c43 > a044 by 0
# Wrong   8c43 > 8d45 by -3
# Correct fe28 > 1953 by 0
# Wrong   c926 > 4c41 by -1
# Correct 8c43 < cb76 by -7
# Correct 63e1 > ad47 by 5
# Correct 63e1 > 6b4e by 6
# Wrong   c926 > 1953 by -1
# Wrong   cb76 > 4c41 by -7
# Correct 8c43 < 63e1 by -14
# Correct 6b4e < ad47 by -1
# Correct ad47 > 6f62 by 7
# Wrong   cb76 > 1953 by -7
# Correct 63e1 < 4c41 by 0
# Correct 44bd > c938 by 0
# Correct 9eb2 > fb4b by 0
# Correct 9eb2 < baa4 by -17
# Wrong   44bd < baa4 by 2
# Correct 4c41 > baa4 by 3
# Correct 4c41 > 1953 by 0
# Wrong   63e1 < baa4 by 3
# Correct 44bd > c938 by 0
# Correct 9eb2 > fb4b by 0
# Correct 9eb2 < 21de by -7
# Correct 44bd > 21de by 12
# Wrong   baa4 > 1953 by -3
# Correct 63e1 > 44bd by 1
# Correct 8c43 < ad47 by -9
# Wrong   6b4e < 6f62 by 6
# Correct 6f62 > 6c5b by 6
# Correct 63e1 > 1953 by 0
# Wrong   ad47 > 44bd by -4
# Correct 8c43 < 6f62 by -2
# Correct 6b4e > 6c5b by 12
# Correct 6b4e > 146f by 14
# Wrong   ad47 > 1953 by -5
# Correct 6f62 < 44bd by -11
# Correct 21de < c938 by -12
# Correct 3669 > 8ac3 by 16
# Correct 3669 > 066e by 7
# Wrong   44bd > 1953 by -1
# Correct 6f62 < c938 by -11
# Correct 21de < 3669 by -13
# Wrong   066e < 8ac3 by 9
# Wrong   8ac3 > 4ca2 by -6
# Wrong   c938 > 1953 by -1
# Correct 6f62 < 3669 by -12
# Correct 21de > 8ac3 by 3
# Correct 9eb2 > fb4b by 0
# Wrong   9eb2 > 4ca2 by -10
# Correct 3669 > 1953 by 0
# Correct 6f62 > 21de by 1
# Wrong   8c43 > 6b4e by -8
# Wrong   8d45 < a044 by 3
# Wrong   a044 > 066e by -7
# Correct 6f62 < 1953 by -12
# Correct b56b < 23a6 by -9
# Correct d28c > b14b by 2
# Correct d28c > fb4b by 20
# Correct 6f62 < 23a6 by -7
# Correct b56b < d28c by -14
# Correct fb4b < b14b by -18
# Correct b14b > 4ca2 by 8
# Correct 6f62 < d28c by -12
# Correct b56b < b14b by -12
# Wrong   fb4b > 4ca2 by -10
# Wrong   fb4b > 6c5b by -2
# Correct 6f62 < b14b by -10
# Correct b56b > fb4b by 6
# Correct abd2 > 4c2a by 0
# Correct abd2 > 146f by 9
# Correct 6f62 > b56b by 2
# Correct 8c43 < 21de by -1
# Correct 9eb2 < 8ac3 by -4
# Wrong   8ac3 > 066e by -9
# Correct 21de > b56b by 1
# Correct 8c43 > 8ac3 by 2
# Correct a044 < 6b4e by -8
# Correct 6b4e > 8d45 by 5
# Correct 8c43 > b56b by 0
# Correct 6b4e > 8ac3 by 10
# Wrong   a044 > 8d45 by -3
# Wrong   a044 > 4ca2 by -4
# Correct 6b4e > b56b by 8
# Correct a044 > 8ac3 by 2
# Correct 4ca2 > 8d45 by 1
# Correct 4ca2 > 6c5b by 8
# Correct a044 < b56b by 0
# Correct abd2 > fb4b by 9
# Correct 146f < 4c2a by -9
# Correct abd2 > 4c2a by 0
# Wrong   a044 > abd2 by -3
# Wrong   4ca2 < 8ac3 by 6
# Wrong   9eb2 > 066e by -13
# Correct 9eb2 > 146f by 0
# Wrong   8ac3 > abd2 by -5
# Correct 4ca2 > 9eb2 by 10
# Wrong   6c5b > 8d45 by -7
# Correct 6c5b < 066e by -11
# Wrong   4ca2 > 066e by -3
# Wrong   4ca2 < abd2 by 1
# Correct 4c2a > fb4b by 9
# Correct 4c2a > 146f by 9
# Wrong   4ca2 < 4c2a by 1
# Correct 146f > fb4b by 0
# Correct 146f < 8d45 by -9
# Correct 4c2a > 8d45 by 0
# Correct 4ca2 > 8d45 by 1
# Correct 066e > 9eb2 by 13
# Correct 066e > 6c5b by 11
# Correct 066e > 8d45 by 4
# Correct 6c5b > 9eb2 by 2
# Correct 6c5b > fb4b by 2
# Wrong   6c5b > 8d45 by -7
# Correct fb4b > 9eb2 by 0
# Correct fb4b > 146f by 0
# Wrong   fb4b > 8d45 by -9
# Correct 146f > 9eb2 by 0
# Correct 146f < 8d45 by -9
# Correct 8d45 > 9eb2 by 9
# Correct 146f > 9eb2 by 0
# Correct 146f < fe28 by -20
# Correct fe28 > c926 by 1
# Wrong   8d45 < 8eaf by 2
# Wrong   8eaf > 88a6 by -12
# Wrong   6f62 > 6b4e by -6
# Correct 6f62 < b14b by -10
# Wrong   23a6 > d28c by -5
# Correct 23a6 > 21de by 8
# Correct b56b > 6c5b by 4
# Wrong   b56b > 4c2a by -3
# Correct 1953 > 2281 by 0
# Correct 1953 > 066e by 7
# Correct c938 > 8ac3 by 15
# Wrong   c938 > 3669 by -1
# Correct 9eb2 < eac9 by -20
# Correct eac9 > 4c41 by 0
# Wrong   cb76 > ad47 by -2
# Wrong   cb76 > 63e1 by -7
# Wrong   8eaf > fe28 by -13
# Correct 8d45 < 88a6 by -10
# Correct 88a6 > 8c43 by 13
# Wrong   23a6 > b14b by -3
# Correct 21de < d28c by -13
# Correct d28c > baa4 by 3
# Correct 1953 > b56b by 14
# Correct 066e < 2281 by -7
# Correct 2281 > abd2 by 11
# Correct eac9 > c938 by 1
# Correct 9eb2 < 4c41 by -20
# Correct 4c41 > 44bd by 1
# Wrong   8eaf > cb76 by -6
# Wrong   88a6 > fe28 by -1
# Wrong   8d45 < 8c43 by 3
# Correct 8c43 < 7cc7 by -14
# Correct 88a6 < 7cc7 by -1
# Correct 8eaf < 7cc7 by -13
# Correct 1953 > 23a6 by 5
# Correct 2281 > b56b by 14
# Correct 066e > abd2 by 4
# Correct 066e > 4ca2 by 3
# Correct 7cc7 > eac9 by 0
# Wrong   8eaf > cb76 by -6
# Wrong   88a6 > fe28 by -1
# Wrong   8d45 < 8c43 by 3
# Correct 8c43 > a044 by 0
# Correct 7cc7 > 1953 by 0
# Wrong   8eaf > eac9 by -13
# Correct 88a6 > cb76 by 6
# Correct 8c43 < fe28 by -14
# Correct 146f < c926 by -19
# Correct c926 > fb4b by 19
# Wrong   8eaf > 1953 by -13
# Correct 88a6 < eac9 by -1
# Correct 4c41 > c938 by 1
# Correct 9eb2 < 44bd by -19
# Correct 44bd > fb4b by 19
# Correct eac9 > 1953 by 0
# Correct 88a6 < 4c41 by -1
# Correct 44bd < c938 by 0
# Correct 3669 > 8ac3 by 16
# Correct 3669 > 146f by 20
# Correct 4c41 > 1953 by 0
# Correct 88a6 > c938 by 0
# Correct fe28 > cb76 by 7
# Correct 8c43 < c926 by -13
# Correct c926 > a044 by 13
# Wrong   88a6 > 1953 by -1
# Correct fe28 > c938 by 1
# Correct c926 > cb76 by 6
# Correct 8c43 > a044 by 0
# Wrong   8c43 > 8d45 by -3
# Correct fe28 > 1953 by 0
# Correct c926 > c938 by 0
# Correct 8c43 < cb76 by -7
# Correct 63e1 > ad47 by 5
# Correct 63e1 > 6b4e by 6
# Wrong   c926 > 1953 by -1
# Wrong   cb76 > c938 by -6
# Correct 8c43 < 63e1 by -14
# Correct 6b4e < ad47 by -1
# Correct ad47 > 6f62 by 7
# Wrong   cb76 > 1953 by -7
# Correct 63e1 > c938 by 1
# Correct 8c43 < ad47 by -9
# Wrong   6b4e < 6f62 by 6
# Correct 6f62 < baa4 by -9
# Correct ad47 < baa4 by -2
# Wrong   63e1 < baa4 by 3
# Wrong   cb76 > baa4 by -4
# Wrong   baa4 > 1953 by -3
# Correct 63e1 > c938 by 1
# Correct 8c43 < ad47 by -9
# Wrong   6b4e < 6f62 by 6
# Correct 6f62 > 21de by 1
# Correct 63e1 > 1953 by 0
# Wrong   ad47 > c938 by -4
# Wrong   8c43 > 6f62 by -2
# Correct 8d45 > a044 by 3
# Correct 8d45 > 6c5b by 7
# Wrong   ad47 > 1953 by -5
# Correct 8c43 < c938 by -13
# Correct 44bd < 3669 by -1
# Correct 146f < 8ac3 by -4
# Wrong   8ac3 > 4c2a by -5
# Wrong   c938 > 1953 by -1
# Correct 8c43 < 3669 by -14
# Correct 44bd > 8ac3 by 15
# Correct 9eb2 > fb4b by 0
# Wrong   9eb2 > abd2 by -9
# Correct 3669 > 1953 by 0
# Correct 8c43 < 44bd by -13
# Correct 9eb2 < 8ac3 by -4
# Correct 146f < 4c2a by -9
# Wrong   4c2a > 4ca2 by -1
# Wrong   44bd > 1953 by -1
# Correct 8c43 > 8ac3 by 2
# Wrong   8d45 < 6f62 by 1
# Correct 6b4e > 21de by 7
# Correct 6b4e > 4ca2 by 4
# Correct 8c43 < 1953 by -14
# Correct 2281 > 23a6 by 5
# Wrong   066e < b56b by 7
# Correct b56b > 146f by 6
# Correct 8c43 < 2281 by -14
# Correct b56b < 23a6 by -9
# Correct d28c > b14b by 2
# Correct d28c > fb4b by 20
# Correct 8c43 < 23a6 by -9
# Correct b56b < d28c by -14
# Correct fb4b < b14b by -18
# Correct b14b > abd2 by 9
# Correct 8c43 < d28c by -14
# Correct b56b < b14b by -12
# Wrong   fb4b > abd2 by -9
# Correct fb4b < 21de by -7
# Correct b14b > 21de by 11
# Correct 8c43 < b14b by -12
# Wrong   b56b > 21de by -1
# Correct 066e > 146f by 13
# Correct 066e > 4ca2 by 3
# Correct 8c43 < b56b by 0
# Correct 066e > 21de by 6
# Correct 4ca2 > 146f by 10
# Wrong   4ca2 < a044 by 4
# Correct 066e > a044 by 7
# Wrong   8c43 > 066e by -7
# Correct 6f62 > 8ac3 by 4
# Correct 8d45 < 6b4e by -5
# Correct 6b4e > 6c5b by 12
# Wrong   6f62 > 066e by -5
# Correct 6b4e > 8ac3 by 10
# Correct 8d45 > 6c5b by 7
# Correct 8d45 < abd2 by 0
# Correct 6b4e > abd2 by 5
# Correct 6b4e > 066e by 1
# Correct abd2 > 8ac3 by 5
# Correct 8d45 > 6c5b by 7
# Correct 8d45 > fb4b by 9
# Correct abd2 < 066e by -4
# Correct a044 < 21de by -1
# Correct 21de > 146f by 7
# Wrong   abd2 < 21de by 2
# Correct a044 > 146f by 6
# Wrong   a044 > 4ca2 by -4
# Correct abd2 > a044 by 3
# Correct 8d45 > 8ac3 by 5
# Wrong   fb4b > 6c5b by -2
# Correct fb4b < 4c2a by -9
# Correct 8d45 < 4c2a by 0
# Correct abd2 < 4c2a by 0
# Correct abd2 > a044 by 3
# Correct 8d45 > 8ac3 by 5
# Wrong   fb4b > 6c5b by -2
# Correct fb4b > 9eb2 by 0
# Correct 8d45 > a044 by 3
# Correct fb4b < 8ac3 by -4
# Correct 8ac3 > 6c5b by 2
# Wrong   8ac3 > a044 by -2
# Wrong   fb4b > 6c5b by -2
# Correct fb4b > 9eb2 by 0
# Correct fb4b < a044 by -6
# Correct 4ca2 > 146f by 10
# Wrong   fb4b > 4ca2 by -10
# Wrong   9eb2 > 6c5b by -2
# Correct 9eb2 > 146f by 0
# Wrong   9eb2 > 4ca2 by -10
# Wrong   146f > 6c5b by -2
# Correct 146f < 4ca2 by -10
# Correct 4ca2 > 6c5b by 8
# Wrong   146f > 6c5b by -2
# Correct 88a6 < 2281 by -1
# Correct 2281 > b14b by 2
# Correct eac9 < 7cc7 by 0
# Correct 7cc7 > b56b by 14
# Wrong   23a6 > 4c41 by -5
# Correct 23a6 > 21de by 8
# Correct fe28 > 8eaf by 13
# Correct fe28 > 8c43 by 14
# Wrong   cb76 > c926 by -6
# Correct cb76 > 6f62 by 5
# Wrong   63e1 < c938 by 1
# Correct c938 > a044 by 13
# Correct 44bd > ad47 by 4
# Correct 44bd > 066e by 6
# Correct 1953 > 3669 by 0
# Correct 1953 > abd2 by 11
# Wrong   baa4 > d28c by -3
# Correct baa4 > 4c2a by 8
# Correct 7cc7 > 2281 by 0
# Correct eac9 > b56b by 14
# Correct eac9 > 8d45 by 11
# Wrong   fe28 < 23a6 by 5
# Correct 21de < 4c41 by -13
# Correct 4c41 > 8ac3 by 16
# Correct c938 > cb76 by 6
# Correct 63e1 > a044 by 14
# Correct 63e1 > 6b4e by 6
# Correct 1953 > 44bd by 1
# Correct abd2 < 3669 by -11
# Correct 3669 > 4ca2 by 10
# Correct 7cc7 > baa4 by 3
# Correct eac9 < 2281 by 0
# Wrong   88a6 < b14b by 1
# Correct b14b > 6c5b by 16
# Correct c938 > 23a6 by 4
# Wrong   63e1 < cb76 by 7
# Correct 6f62 < c926 by -11
# Correct c926 > 9eb2 by 19
# Correct 7cc7 > 1953 by 0
# Correct 2281 > baa4 by 3
# Correct eac9 > b14b by 2
# Wrong   8d45 < b56b by 3
# Correct b56b > 146f by 6
# Correct 7cc7 > c938 by 1
# Correct 2281 > 1953 by 0
# Correct eac9 > baa4 by 3
# Correct b56b < b14b by -12
# Correct 88a6 > 6c5b by 17
# Correct 88a6 > fb4b by 19
# Correct 2281 > c938 by 1
# Correct eac9 > 1953 by 0
# Correct b14b > baa4 by 1
# Correct b56b < 88a6 by -13
# Wrong   fb4b > 6c5b by -2
# Correct eac9 > c938 by 1
# Wrong   b14b > 1953 by -2
# Wrong   88a6 < baa4 by 2
# Correct 4c2a < d28c by -11
# Correct d28c > 6c5b by 18
# Wrong   b14b > c938 by -1
# Wrong   baa4 > 1953 by -3
# Correct 88a6 < d28c by -1
# Correct 4c2a > 6c5b by 7
# Correct 4c2a > 146f by 9
# Wrong   baa4 > c938 by -2
# Correct d28c > 1953 by 0
# Correct 88a6 > 4c2a by 10
# Correct b56b > fb4b by 6
# Wrong   b56b > 8d45 by -3
# Correct d28c > c938 by 1
# Wrong   88a6 > 1953 by -1
# Wrong   b56b > 4c2a by -3
# Correct 8d45 > fb4b by 9
# Wrong   8d45 < 8ac3 by 5
# Correct b56b > 8ac3 by 2
# Correct 88a6 > c938 by 0
# Correct b56b < 1953 by -14
# Correct 3669 > 44bd by 1
# Wrong   abd2 > 4ca2 by -1
# Wrong   abd2 < 21de by 2
# Correct 3669 > 21de by 13
# Correct 1953 > c938 by 1
# Correct b56b < 3669 by -14
# Correct 21de < 44bd by -12
# Correct 066e < ad47 by -2
# Correct ad47 > 8eaf by 8
# Correct 3669 > c938 by 1
# Correct b56b < 44bd by -13
# Correct 21de < ad47 by -8
# Wrong   066e < 8eaf by 6
# Correct 8eaf > 8c43 by 1
# Correct 44bd < c938 by 0
# Correct cb76 < 23a6 by -2
# Correct fe28 > 4c41 by 0
# Correct fe28 > 9eb2 by 20
# Wrong   44bd < 23a6 by 4
# Wrong   cb76 > fe28 by -7
# Wrong   63e1 < c926 by 1
# Correct c926 > 6f62 by 11
# Correct 44bd > cb76 by 6
# Correct b56b < ad47 by -9
# Correct 21de < 8eaf by 0
# Wrong   066e < 8c43 by 7
# Correct 8c43 > a044 by 0
# Correct ad47 > cb76 by 2
# Correct b56b < 8eaf by -1
# Wrong   21de < 8c43 by 1
# Correct 066e > a044 by 7
# Wrong   066e > 6b4e by -1
# Wrong   8eaf > cb76 by -6
# Correct b56b > 8c43 by 0
# Correct 8ac3 < 4c2a by -5
# Wrong   146f > 6c5b by -2
# Correct 146f < a044 by -6
# Correct 4c2a > a044 by 3
# Correct b56b < cb76 by -7
# Wrong   c926 > fe28 by -1
# Correct 63e1 > 6f62 by 12
# Correct 63e1 > 6b4e by 6
# Correct b56b < c926 by -13
# Correct 63e1 < fe28 by 0
# Correct 9eb2 < 4c41 by -20
# Correct 4c41 > 4ca2 by 10
# Correct b56b < fe28 by -14
# Correct 63e1 < 4c41 by 0
# Correct 9eb2 < 4ca2 by -10
# Correct 4ca2 > abd2 by 1
# Correct b56b < 4c41 by -14
# Correct 63e1 > 4ca2 by 10
# Wrong   6b4e < 6f62 by 6
# Correct 6f62 > 6c5b by 6
# Correct b56b < 63e1 by -14
# Wrong   6f62 > 4ca2 by -2
# Correct 6b4e > 6c5b by 12
# Correct 6b4e > 146f by 14
# Wrong   b56b > 6f62 by -2
# Wrong   4c2a < 8c43 by 3
# Wrong   21de > 066e by -6
# Correct 21de > fb4b by 7
# Wrong   8c43 > 6f62 by -2
# Correct 4c2a > 21de by 2
# Correct 8ac3 < a044 by -2
# Wrong   a044 > 8d45 by -3
# Correct 4c2a > 6f62 by 1
# Wrong   a044 > 21de by -1
# Correct 8ac3 < 8d45 by -5
# Correct 8d45 < abd2 by 0
# Wrong   a044 > abd2 by -3
# Correct a044 < 6f62 by -2
# Correct 6b4e > 4ca2 by 4
# Wrong   146f > 6c5b by -2
# Correct 146f > 9eb2 by 0
# Wrong   a044 > 6b4e by -8
# Wrong   abd2 < 21de by 2
# Correct fb4b < 066e by -13
# Correct 066e > 6c5b by 11
# Wrong   21de > 6b4e by -7
# Correct abd2 < 066e by -4
# Wrong   fb4b > 6c5b by -2
# Correct fb4b < 9eb2 by 0
# Correct 066e > 9eb2 by 13
# Wrong   066e > 6b4e by -1
# Correct abd2 > 9eb2 by 9
# Correct 8ac3 < 8d45 by -5
# Correct 8d45 > 6c5b by 7
# Wrong   abd2 > 6b4e by -5
# Correct 8d45 > 9eb2 by 9
# Correct 8ac3 > 6c5b by 2
# Correct 8ac3 > fb4b by 4
# Correct 8d45 < 6b4e by -5
# Correct 146f < 4ca2 by -10
# Correct 4ca2 > 6c5b by 8
# Wrong   8d45 > 4ca2 by -1
# Correct 8ac3 > 9eb2 by 4
# Correct 8ac3 > fb4b by 4
# Wrong   8ac3 > 4ca2 by -6
# Correct fb4b < 9eb2 by 0
# Correct 9eb2 < 6c5b by -2
# Correct 8ac3 > 6c5b by 2
# Correct 6c5b < 4ca2 by -8
# Correct 4ca2 > 146f by 10
# Correct 6c5b > 146f by 2
# Correct fb4b < 9eb2 by 0
# Correct 6c5b > 9eb2 by 2
# Correct 9eb2 > 146f by 0
# Correct 9eb2 > fb4b by 0
# Correct fb4b > 146f by 0
# Correct 2281 > 7cc7 by 0
# Correct 2281 > 63e1 by 0
# Wrong   b14b > eac9 by -2
# Correct b14b > b56b by 12
# Correct d28c > baa4 by 3
# Correct d28c > 8c43 by 14
# Correct 1953 > 88a6 by 1
# Correct 1953 > 4c2a by 11
# Wrong   c938 > 3669 by -1
# Correct c938 > 6f62 by 11
# Wrong   44bd < 23a6 by 4
# Correct 23a6 > a044 by 9
# Wrong   8eaf > ad47 by -8
# Correct 8eaf > 21de by 0
# Correct c926 > cb76 by 6
# Correct c926 > 066e by 6
# Correct 4c41 > fe28 by 0
# Correct 4c41 > abd2 by 11
# Wrong   b14b > 2281 by -2
# Correct b56b < eac9 by -14
# Correct eac9 > 6b4e by 6
# Correct 1953 > d28c by 0
# Correct 4c2a < 88a6 by -10
# Correct 88a6 > 8d45 by 10
# Wrong   23a6 > c938 by -4
# Correct 44bd > a044 by 13
# Correct 44bd > 8ac3 by 15
# Correct c926 > 8eaf by 12
# Correct 066e < cb76 by 0
# Correct cb76 > 4ca2 by 3
# Wrong   b14b > 4c41 by -2
# Correct eac9 < 2281 by 0
# Correct 63e1 < 7cc7 by 0
# Correct 7cc7 > 6c5b by 18
# Wrong   23a6 > 1953 by -5
# Correct 44bd < c938 by 0
# Correct 6f62 < 3669 by -12
# Correct 3669 > 9eb2 by 20
# Wrong   b14b > c926 by -1
# Correct 2281 > 4c41 by 0
# Correct eac9 < 7cc7 by 0
# Correct 63e1 > 6c5b by 18
# Correct 63e1 > fb4b by 20
# Correct b14b > 23a6 by 3
# Correct 2281 > c926 by 1
# Correct 7cc7 > 4c41 by 0
# Correct eac9 > 63e1 by 0
# Wrong   b56b > 6b4e by -8
# Correct b56b > 146f by 6
# Correct 2281 > 23a6 by 5
# Correct 7cc7 > c926 by 1
# Correct eac9 > 4c41 by 0
# Correct b56b < 63e1 by -14
# Wrong   fb4b > 6c5b by -2
# Correct 7cc7 > 23a6 by 5
# Correct eac9 > c926 by 1
# Correct 63e1 < 4c41 by 0
# Correct abd2 < fe28 by -11
# Correct fe28 > 6c5b by 18
# Correct eac9 > 23a6 by 5
# Correct 4c41 > c926 by 1
# Correct 63e1 < fe28 by 0
# Correct abd2 > 6c5b by 7
# Wrong   abd2 > 6b4e by -5
# Correct 4c41 > 23a6 by 5
# Correct fe28 > c926 by 1
# Correct 63e1 > abd2 by 11
# Correct b56b > fb4b by 6
# Correct b56b > 146f by 6
# Wrong   fe28 < 23a6 by 5
# Wrong   c938 > 1953 by -1
# Wrong   44bd > 3669 by -1
# Correct 8ac3 < a044 by -2
# Correct a044 < baa4 by -11
# Wrong   44bd < baa4 by 2
# Correct c938 > baa4 by 2
# Correct fe28 > c938 by 1
# Wrong   63e1 < c926 by 1
# Correct cb76 > 8eaf by 6
# Correct 066e > 4ca2 by 3
# Wrong   066e < 8c43 by 7
# Correct cb76 > 8c43 by 7
# Correct c926 > c938 by 0
# Wrong   63e1 < cb76 by 7
# Correct 8c43 < 8eaf by -1
# Correct 21de < ad47 by -8
# Correct ad47 > 8d45 by 6
# Wrong   cb76 > c938 by -6
# Wrong   63e1 < 8eaf by 13
# Correct 8c43 < ad47 by -9
# Wrong   21de > 8d45 by -2
# Wrong   21de > 4c2a by -2
# Wrong   8eaf > c938 by -12
# Correct 63e1 > ad47 by 5
# Wrong   b56b > abd2 by -3
# Correct 146f > fb4b by 0
# Correct 146f > 9eb2 by 0
# Wrong   63e1 < c938 by 1
# Wrong   baa4 > 1953 by -3
# Wrong   44bd > 3669 by -1
# Correct 8ac3 < a044 by -2
# Correct a044 < 6f62 by -2
# Correct 44bd > 6f62 by 11
# Wrong   63e1 < baa4 by 3
# Wrong   44bd > 1953 by -1
# Correct 6f62 < 3669 by -12
# Correct 3669 > a044 by 14
# Correct 63e1 > 44bd by 1
# Correct b56b < ad47 by -9
# Correct 8c43 < 21de by -1
# Correct 4c2a > 8d45 by 0
# Correct 4c2a > 8ac3 by 5
# Wrong   ad47 > 44bd by -4
# Wrong   b56b > 21de by -1
# Correct 146f < abd2 by -9
# Correct 6b4e > 6c5b by 12
# Correct 6b4e > 8d45 by 5
# Correct b56b < 44bd by -13
# Correct 3669 > 1953 by 0
# Correct 6f62 > a044 by 2
# Correct 6f62 > 8ac3 by 4
# Correct b56b < 3669 by -14
# Correct 6f62 < 1953 by -12
# Correct 88a6 < d28c by -1
# Correct d28c > 4ca2 by 10
# Correct b56b < 1953 by -14
# Correct 6f62 < d28c by -12
# Correct 88a6 > 4ca2 by 9
# Correct 88a6 > 066e by 6
# Correct b56b < d28c by -14
# Correct 6f62 < 88a6 by -11
# Correct 066e > 4ca2 by 3
# Correct 066e > 6c5b by 11
# Correct b56b < 88a6 by -13
# Wrong   6f62 > 066e by -5
# Correct 8ac3 < a044 by -2
# Wrong   a044 > 8d45 by -3
# Wrong   b56b > 6f62 by -2
# Wrong   abd2 < 21de by 2
# Wrong   8c43 > 4c2a by -3
# Correct 8c43 > fb4b by 6
# Correct 21de < 6f62 by -1
# Wrong   a044 > 066e by -7
# Correct 8ac3 < 8d45 by -5
# Correct 8d45 > 9eb2 by 9
# Correct 21de > a044 by 1
# Wrong   abd2 < 8c43 by 3
# Correct fb4b < 4c2a by -9
# Wrong   4c2a > 4ca2 by -1
# Correct 8c43 > a044 by 0
# Correct abd2 > 4c2a by 0
# Correct 146f < 6b4e by -14
# Correct 6b4e > 6c5b by 12
# Wrong   abd2 < a044 by 3
# Correct 8d45 < 066e by -4
# Correct 066e > 9eb2 by 13
# Correct abd2 < 066e by -4
# Correct 8d45 > 9eb2 by 9
# Wrong   8d45 < 8ac3 by 5
# Correct 066e > 8ac3 by 9
# Correct abd2 > 8ac3 by 5
# Wrong   6b4e < 4c2a by 5
# Correct fb4b < 4ca2 by -10
# Wrong   4c2a > 4ca2 by -1
# Correct 4c2a > 8ac3 by 5
# Correct 6b4e > 4ca2 by 4
# Wrong   146f > 6c5b by -2
# Correct 146f > fb4b by 0
# Correct 6b4e > 8ac3 by 10
# Correct 146f < 4ca2 by -10
# Correct 4ca2 > 6c5b by 8
# Correct 4ca2 > 8ac3 by 6
# Wrong   146f > 6c5b by -2
# Correct 146f > fb4b by 0
# Correct 146f < 8ac3 by -4
# Correct 8d45 > 9eb2 by 9
# Correct 146f < 8d45 by -9
# Correct 8d45 > 9eb2 by 9
# Correct 146f > 9eb2 by 0
# Wrong   fb4b > 6c5b by -2
# Correct fb4b < 9eb2 by 0
# Correct 9eb2 < 6c5b by -2
# Correct fb4b < 9eb2 by 0
# Correct 2281 > b14b by 2
# Correct 2281 > 88a6 by 1
# Correct eac9 < 7cc7 by 0
# Correct 7cc7 > b56b by 14
# Wrong   23a6 > 4c41 by -5
# Correct 23a6 > 6f62 by 7
# Wrong   c926 > fe28 by -1
# Correct c926 > 21de by 12
# Wrong   8eaf > cb76 by -6
# Correct 8eaf > 8c43 by 1
# Wrong   baa4 > c938 by -2
# Correct baa4 > a044 by 11
# Wrong   ad47 > 63e1 by -5
# Correct ad47 > 066e by 2
# Correct 3669 > 44bd by 1
# Correct 3669 > abd2 by 11
# Correct d28c > 1953 by 0
# Correct d28c > 4c2a by 11
# Correct 7cc7 > 2281 by 0
# Correct eac9 > b56b by 14
# Correct eac9 > 6b4e by 6
# Wrong   c926 < 23a6 by 4
# Correct 6f62 < 4c41 by -12
# Correct 4c41 > 4ca2 by 10
# Correct baa4 > 8eaf by 10
# Correct a044 < c938 by -13
# Correct c938 > 8ac3 by 15
# Correct 3669 > ad47 by 5
# Correct abd2 < 44bd by -10
# Correct 44bd > 8d45 by 10
# Correct 7cc7 > d28c by 0
# Correct eac9 < 2281 by 0
# Wrong   88a6 < b14b by 1
# Correct b14b > 146f by 18
# Wrong   baa4 < 23a6 by 2
# Wrong   c926 > 4c41 by -1
# Correct 21de < fe28 by -13
# Correct fe28 > 6c5b by 18
# Correct 7cc7 > 3669 by 0
# Correct 2281 > d28c by 0
# Correct eac9 > b14b by 2
# Wrong   6b4e < b56b by 8
# Correct b56b > 9eb2 by 6
# Correct 7cc7 > 23a6 by 5
# Correct 2281 > 3669 by 0
# Correct eac9 > d28c by 0
# Correct b56b < b14b by -12
# Correct 88a6 > 146f by 19
# Correct 88a6 > fb4b by 19
# Correct 2281 > 23a6 by 5
# Correct eac9 > 3669 by 0
# Wrong   b14b > d28c by -2
# Correct b56b < 88a6 by -13
# Correct fb4b > 146f by 0
# Correct eac9 > 23a6 by 5
# Wrong   b14b > 3669 by -2
# Correct 88a6 < d28c by -1
# Correct 4c2a < 1953 by -11
# Correct 1953 > 146f by 20
# Correct b14b > 23a6 by 3
# Correct d28c > 3669 by 0
# Wrong   88a6 > 1953 by -1
# Correct b56b > fb4b by 6
# Correct 6b4e > 9eb2 by 14
# Correct d28c > 23a6 by 5
# Wrong   88a6 > 3669 by -1
# Correct b56b < 1953 by -14
# Correct 4c2a > 146f by 9
# Correct 4c2a > 9eb2 by 9
# Correct 88a6 > 23a6 by 4
# Correct 1953 > 3669 by 0
# Wrong   b56b > 4c2a by -3
# Correct 6b4e > fb4b by 14
# Correct 6b4e > 4ca2 by 4
# Wrong   1953 < 23a6 by 5
# Wrong   baa4 > c926 by -2
# Correct c938 > 8eaf by 12
# Correct a044 > 8ac3 by 2
# Correct a044 < 6f62 by -2
# Correct c938 > 6f62 by 11
# Wrong   1953 < baa4 by 3
# Correct c938 > c926 by 0
# Wrong   6f62 < 8eaf by 1
# Correct 8c43 < cb76 by -7
# Correct cb76 > 6c5b by 11
# Correct 1953 > c938 by 1
# Correct b56b < 3669 by -14
# Correct 44bd > ad47 by 4
# Correct abd2 > 8d45 by 0
# Wrong   abd2 < 21de by 2
# Correct 44bd > 21de by 12
# Correct 3669 > c938 by 1
# Correct b56b < 44bd by -13
# Correct 21de < ad47 by -8
# Correct 066e < 63e1 by -7
# Correct 63e1 > 6c5b by 18
# Correct 44bd < c938 by 0
# Correct 8eaf < c926 by -12
# Correct fe28 > 4c41 by 0
# Correct fe28 > 8c43 by 14
# Correct 44bd > c926 by 0
# Correct b56b < ad47 by -9
# Correct 21de < 63e1 by -13
# Correct 066e > 6c5b by 11
# Correct 066e > 8ac3 by 9
# Correct ad47 < c926 by -4
# Wrong   8eaf > fe28 by -13
# Correct 6f62 < cb76 by -5
# Correct cb76 > a044 by 7
# Correct ad47 > 8eaf by 8
# Correct b56b < 63e1 by -14
# Wrong   21de > 066e by -6
# Correct abd2 > 8d45 by 0
# Correct abd2 > 6c5b by 7
# Wrong   63e1 < 8eaf by 13
# Wrong   cb76 > fe28 by -7
# Correct 6f62 > a044 by 2
# Correct 6f62 > 8ac3 by 4
# Wrong   63e1 < cb76 by 7
# Correct 6f62 < fe28 by -12
# Correct 8c43 < 4c41 by -14
# Correct 4c41 > 8d45 by 11
# Correct 63e1 < fe28 by 0
# Correct 6f62 < 4c41 by -12
# Wrong   8c43 > 8d45 by -3
# Correct 8c43 > 6c5b by 4
# Correct 63e1 < 4c41 by 0
# Correct 6f62 > 8c43 by 2
# Correct 8ac3 < a044 by -2
# Correct a044 > 146f by 6
# Correct 63e1 > 6f62 by 12
# Wrong   b56b > 21de by -1
# Wrong   6b4e < 4c2a by 5
# Correct 4c2a > 9eb2 by 9
# Wrong   b56b > 6f62 by -2
# Correct 4c2a > 21de by 2
# Correct 6b4e > 9eb2 by 14
# Correct 4ca2 > fb4b by 10
# Correct 4c2a > 6f62 by 1
# Correct 6b4e > 21de by 7
# Correct 4ca2 > 9eb2 by 10
# Correct 4ca2 > fb4b by 10
# Wrong   6b4e < 6f62 by 6
# Correct a044 < 8c43 by 0
# Correct 6c5b < 8d45 by -7
# Wrong   8c43 > 8d45 by -3
# Wrong   6b4e < 8c43 by 8
# Wrong   a044 > 8d45 by -3
# Correct 8ac3 > 146f by 4
# Correct 8ac3 > 6c5b by 2
# Wrong   6b4e < a044 by 8
# Correct 8ac3 < 8d45 by -5
# Correct 8d45 > 146f by 9
# Correct 6b4e > 8d45 by 5
# Wrong   4ca2 < 21de by 3
# Correct abd2 < 066e by -4
# Correct 066e > 6c5b by 11
# Wrong   21de > 8d45 by -2
# Wrong   4ca2 > 066e by -3
# Correct fb4b < 9eb2 by 0
# Correct 9eb2 < 6c5b by -2
# Correct 4ca2 > 6c5b by 8
# Correct 4ca2 > 8d45 by 1
# Correct 6c5b < 066e by -11
# Correct 066e > abd2 by 4
# Correct 066e > 8d45 by 4
# Correct 6c5b < abd2 by -7
# Correct abd2 > 9eb2 by 9
# Correct abd2 > 8d45 by 0
# Correct 6c5b > 9eb2 by 2
# Correct 6c5b > fb4b by 2
# Correct 6c5b < 8d45 by -7
# Correct 8ac3 > 146f by 4
# Correct 6c5b < 8ac3 by -2
# Correct 8ac3 > 146f by 4
# Correct 6c5b > 146f by 2
# Correct fb4b < 9eb2 by 0
# Correct 6c5b > 9eb2 by 2
# Correct 9eb2 > 146f by 0
# Correct 9eb2 > fb4b by 0
# Correct fb4b > 146f by 0
# Correct 2281 > 7cc7 by 0
# Correct 2281 > 63e1 by 0
# Wrong   b14b > eac9 by -2
# Correct b14b > b56b by 12
# Correct 88a6 < d28c by -1
# Correct d28c > 4c2a by 11
# Wrong   baa4 < 23a6 by 2
# Correct 23a6 > 6f62 by 7
# Correct 3669 > 1953 by 0
# Correct 3669 > 8c43 by 14
# Correct 44bd > c938 by 0
# Correct 44bd > a044 by 13
# Correct ad47 < c926 by -4
# Correct c926 > 6b4e by 5
# Correct cb76 > 8eaf by 6
# Correct cb76 > 21de by 6
# Correct 4c41 > fe28 by 0
# Correct 4c41 > 4ca2 by 10
# Wrong   b14b > 2281 by -2
# Correct b56b < eac9 by -14
# Correct eac9 > 066e by 7
# Wrong   23a6 > d28c by -5
# Correct baa4 > 6f62 by 9
# Correct baa4 > abd2 by 8
# Wrong   44bd > 3669 by -1
# Correct a044 < c938 by -13
# Correct c938 > 8d45 by 10
# Wrong   cb76 > c926 by -6
# Correct 21de < 8eaf by 0
# Correct 8eaf > 8ac3 by 3
# Wrong   b14b > 4c41 by -2
# Correct eac9 < 2281 by 0
# Correct 63e1 < 7cc7 by 0
# Correct 7cc7 > 6c5b by 18
# Wrong   44bd < 23a6 by 4
# Wrong   baa4 > d28c by -3
# Wrong   abd2 < 6f62 by 1
# Correct 6f62 > 9eb2 by 8
# Correct b14b > cb76 by 5
# Correct 2281 > 4c41 by 0
# Correct eac9 < 7cc7 by 0
# Correct 63e1 > 6c5b by 18
# Correct 63e1 > fb4b by 20
# Correct b14b > 23a6 by 3
# Correct 2281 > cb76 by 7
# Correct 7cc7 > 4c41 by 0
# Correct eac9 > 63e1 by 0
# Wrong   b56b > 066e by -7
# Correct b56b > 146f by 6
# Correct 2281 > 23a6 by 5
# Correct 7cc7 > cb76 by 7
# Correct eac9 > 4c41 by 0
# Correct b56b < 63e1 by -14
# Correct fb4b < 6c5b by -2
# Correct 63e1 > 6c5b by 18
# Correct 7cc7 > 23a6 by 5
# Correct eac9 > cb76 by 7
# Correct 63e1 < 4c41 by 0
# Correct 4ca2 < fe28 by -10
# Correct fe28 > fb4b by 20
# Wrong   eac9 < 23a6 by 5
# Wrong   44bd < baa4 by 2
# Correct 6f62 < d28c by -12
# Correct 88a6 > 4c2a by 10
# Correct 88a6 > 066e by 6
# Correct eac9 > baa4 by 3
# Correct 4c41 > cb76 by 7
# Correct 63e1 < fe28 by 0
# Correct 4ca2 > fb4b by 10
# Correct 4ca2 > 146f by 10
# Correct 4c41 > baa4 by 3
# Correct fe28 > cb76 by 7
# Correct 63e1 > 4ca2 by 10
# Correct b56b > 6c5b by 4
# Wrong   b56b > 4c2a by -3
# Correct fe28 > baa4 by 3
# Wrong   63e1 < cb76 by 7
# Correct 8eaf < c926 by -12
# Correct ad47 > 6b4e by 1
# Correct ad47 > 066e by 2
# Wrong   cb76 > baa4 by -4
# Wrong   63e1 < c926 by 1
# Wrong   8eaf > ad47 by -8
# Correct 21de > 8ac3 by 3
# Correct 21de > 9eb2 by 7
# Wrong   c926 < baa4 by 2
# Correct 44bd < d28c by -1
# Correct 6f62 < 88a6 by -11
# Correct 88a6 > abd2 by 10
# Wrong   c926 > d28c by -1
# Wrong   63e1 < 8eaf by 13
# Correct 21de < ad47 by -8
# Wrong   066e > 6b4e by -1
# Correct 066e < 1953 by -7
# Wrong   ad47 > 1953 by -5
# Correct 8eaf < d28c by -13
# Correct 44bd < 88a6 by 0
# Wrong   6f62 > abd2 by -1
# Wrong   6f62 < 8c43 by 2
# Correct 88a6 > 8c43 by 13
# Correct 8eaf < 88a6 by -12
# Correct 44bd > 8c43 by 13
# Wrong   c938 > 3669 by -1
# Wrong   a044 > 8d45 by -3
# Wrong   8eaf > 44bd by -12
# Correct 63e1 > ad47 by 5
# Wrong   b56b > 4ca2 by -4
# Correct 4c2a > 6c5b by 7
# Correct 4c2a > 8d45 by 0
# Correct 63e1 > 44bd by 1
# Correct b56b < ad47 by -9
# Correct 21de < 1953 by -13
# Wrong   066e > 6b4e by -1
# Wrong   ad47 > 44bd by -4
# Correct b56b < 1953 by -14
# Wrong   21de > 066e by -6
# Correct 9eb2 < 8ac3 by -4
# Wrong   8ac3 > 6b4e by -10
# Correct 1953 > 44bd by 1
# Wrong   b56b > 21de by -1
# Wrong   4c2a > 4ca2 by -1
# Correct 8d45 > 6c5b by 7
# Correct 8d45 < 6b4e by -5
# Wrong   4c2a > 6b4e by -5
# Correct b56b < 44bd by -13
# Correct c938 > 8c43 by 13
# Correct a044 < 3669 by -14
# Correct 3669 > 9eb2 by 20
# Correct b56b < c938 by -13
# Correct 3669 > 8c43 by 14
# Correct a044 > 9eb2 by 6
# Correct a044 > fb4b by 6
# Correct b56b < 3669 by -14
# Correct a044 < 8c43 by 0
# Wrong   6f62 > abd2 by -1
# Correct 6f62 > 146f by 8
# Correct b56b > 8c43 by 0
# Correct 4c2a > 21de by 2
# Correct 6b4e > 4ca2 by 4
# Correct 8d45 > 6c5b by 7
# Correct 4c2a > 8c43 by 3
# Wrong   6b4e < 21de by 7
# Correct 8ac3 < 066e by -9
# Correct 066e > 6c5b by 11
# Wrong   21de < 8c43 by 1
# Correct a044 < 6f62 by -2
# Correct 146f < abd2 by -9
# Wrong   6f62 > abd2 by -1
# Correct 21de < 6f62 by -1
# Wrong   a044 > abd2 by -3
# Correct fb4b < 9eb2 by 0
# Correct 9eb2 > 146f by 0
# Correct 21de > a044 by 1
# Correct 6b4e > 066e by 1
# Wrong   8d45 > 4ca2 by -1
# Correct 8d45 > 146f by 9
# Wrong   6b4e < a044 by 8
# Correct 9eb2 < abd2 by -9
# Correct abd2 > fb4b by 9
# Correct 6b4e > abd2 by 5
# Correct 8d45 < 066e by -4
# Correct 8ac3 > 6c5b by 2
# Correct 066e > abd2 by 4
# Correct 8d45 > 8ac3 by 5
# Correct 146f < 4ca2 by -10
# Correct 4ca2 > 6c5b by 8
# Correct 8d45 < abd2 by 0
# Correct 9eb2 > fb4b by 0
# Correct 9eb2 < 6c5b by -2
# Correct abd2 > 6c5b by 7
# Correct 8d45 > 6c5b by 7
# Correct 4ca2 > 8ac3 by 6
# Correct 4ca2 > 146f by 10
# Correct 4ca2 > 6c5b by 8
# Correct 146f < 8ac3 by -4
# Correct 8ac3 > fb4b by 4
# Correct 8ac3 > 6c5b by 2
# Correct 146f > fb4b by 0
# Correct 146f > 9eb2 by 0
# Wrong   146f > 6c5b by -2
# Correct 9eb2 > fb4b by 0
# Correct 9eb2 < 6c5b by -2
# Correct 6c5b > fb4b by 2
# Correct 9eb2 > fb4b by 0
# Correct d28c > 4ca2 by 10
# Correct d28c > fe28 by 0
# Correct 63e1 < 4c41 by 0
# Correct 4c41 > a044 by 14
# Correct b14b > 9eb2 by 18
# Correct b14b > abd2 by 9
# Correct 3669 > 146f by 20
# Correct 3669 > 21de by 13
# Correct eac9 > 23a6 by 5
# Correct eac9 > b56b by 14
# Correct 8eaf > 6c5b by 5
# Wrong   8eaf > ad47 by -8
# Wrong   6b4e < 8c43 by 8
# Correct 8c43 < c938 by -13
# Correct fb4b < 44bd by -19
# Correct 44bd < c926 by 0
# Correct 2281 > 1953 by 0
# Correct 2281 > 88a6 by 1
# Correct 4c41 > d28c by 0
# Correct 63e1 > a044 by 14
# Correct 63e1 < 7cc7 by 0
# Correct 4c41 < 7cc7 by 0
# Wrong   3669 < b14b by 2
# Correct abd2 > 9eb2 by 9
# Correct abd2 < 066e by -4
# Correct b14b > 066e by 5
# Correct 8eaf < eac9 by -13
# Correct b56b < 23a6 by -9
# Correct 23a6 > cb76 by 2
# Correct c926 > c938 by 0
# Correct fb4b < 44bd by -19
# Correct 44bd > 8d45 by 10
# Correct 7cc7 > 2281 by 0
# Correct 4c41 > d28c by 0
# Correct 63e1 > a044 by 14
# Correct 63e1 > 4c2a by 11
# Correct eac9 > b14b by 2
# Correct 8eaf < 23a6 by -8
# Correct b56b < cb76 by -7
# Correct cb76 > 6f62 by 5
# Correct 7cc7 > c926 by 1
# Correct 4c41 < 2281 by 0
# Wrong   88a6 > 1953 by -1
# Correct 88a6 > 8ac3 by 15
# Correct 7cc7 > eac9 by 0
# Correct 2281 > c926 by 1
# Correct 4c41 > 88a6 by 1
# Correct 63e1 < d28c by 0
# Correct fe28 > 4ca2 by 10
# Correct fe28 > baa4 by 3
# Correct 2281 > eac9 by 0
# Correct 4c41 > c926 by 1
# Correct d28c > 88a6 by 1
# Correct 63e1 < fe28 by 0
# Correct baa4 > 4ca2 by 7
# Correct 4c41 > eac9 by 0
# Correct d28c > c926 by 1
# Wrong   fe28 < 88a6 by 1
# Correct 8ac3 < 1953 by -16
# Correct 1953 > 4ca2 by 10
# Correct d28c > eac9 by 0
# Correct 88a6 > c926 by 0
# Correct fe28 > 1953 by 0
# Wrong   63e1 < baa4 by 3
# Correct baa4 > a044 by 11
# Wrong   88a6 > eac9 by -1
# Correct fe28 > c926 by 1
# Wrong   baa4 > 1953 by -3
# Correct 63e1 > a044 by 14
# Correct 63e1 > 4c2a by 11
# Correct fe28 > eac9 by 0
# Correct baa4 < c926 by -2
# Correct 44bd > c938 by 0
# Correct fb4b < 8d45 by -9
# Correct 8d45 > 9eb2 by 9
# Correct c926 < eac9 by -1
# Wrong   23a6 > b14b by -3
# Wrong   8eaf > cb76 by -6
# Correct ad47 > 6c5b by 13
# Correct ad47 > abd2 by 6
# Wrong   c926 < 23a6 by 4
# Correct 8eaf < b14b by -11
# Correct 3669 > 066e by 7
# Correct 21de > 146f by 7
# Correct c926 > b14b by 1
# Wrong   baa4 > 44bd by -2
# Correct 63e1 > 1953 by 0
# Correct 4c2a > a044 by 3
# Correct 4c2a > 146f by 9
# Wrong   baa4 > b14b by -1
# Correct 63e1 > 44bd by 1
# Correct 4c2a < 1953 by -11
# Wrong   8ac3 > 4ca2 by -6
# Correct 8ac3 < 6f62 by -4
# Correct 1953 > 6f62 by 12
# Wrong   63e1 < b14b by 2
# Correct 8eaf < 3669 by -13
# Wrong   21de > 066e by -6
# Wrong   21de < b56b by 1
# Correct 3669 > b56b by 14
# Correct 63e1 < 3669 by 0
# Correct 8eaf > b56b by 1
# Correct ad47 > cb76 by 2
# Correct abd2 > 6c5b by 7
# Wrong   63e1 < 8eaf by 13
# Correct ad47 > b56b by 9
# Correct abd2 < cb76 by -4
# Correct cb76 > 6c5b by 11
# Correct 63e1 > ad47 by 5
# Correct 1953 > 44bd by 1
# Correct 4c2a > 6f62 by 1
# Correct 146f < a044 by -6
# Correct a044 < 8c43 by 0
# Correct 4c2a > 8c43 by 3
# Correct 1953 > ad47 by 5
# Correct 4c2a < 44bd by -10
# Correct 8d45 < c938 by -10
# Correct c938 > 6b4e by 5
# Correct 44bd > ad47 by 4
# Correct 4c2a < c938 by -10
# Correct 8d45 < 6b4e by -5
# Correct 6b4e > 9eb2 by 14
# Correct c938 > ad47 by 4
# Wrong   4c2a > 6b4e by -5
# Wrong   8c43 > 6f62 by -2
# Correct 146f < a044 by -6
# Correct a044 > fb4b by 6
# Correct 4c2a < ad47 by -6
# Correct cb76 > b56b by 7
# Correct abd2 > 6c5b by 7
# Wrong   abd2 > 4ca2 by -1
# Correct 4c2a < cb76 by -4
# Wrong   abd2 < b56b by 3
# Wrong   21de > 066e by -6
# Correct 21de > 8ac3 by 3
# Correct 4c2a > b56b by 3
# Wrong   8c43 > 6b4e by -8
# Correct a044 < 6f62 by -2
# Correct 6f62 > fb4b by 8
# Correct 8c43 > b56b by 0
# Wrong   6f62 > 6b4e by -6
# Correct a044 > fb4b by 6
# Correct a044 > 146f by 6
# Correct 6f62 > b56b by 2
# Wrong   a044 > 6b4e by -8
# Correct 146f > fb4b by 0
# Correct 146f < 066e by -13
# Correct a044 < 066e by -7
# Wrong   6f62 > 066e by -5
# Wrong   066e < b56b by 7
# Wrong   abd2 < 21de by 2
# Correct 21de > 8ac3 by 3
# Correct 066e > 21de by 6
# Wrong   a044 > 6b4e by -8
# Correct 146f > fb4b by 0
# Wrong   146f > 6c5b by -2
# Correct a044 < 21de by -1
# Correct abd2 > 8ac3 by 5
# Wrong   abd2 > 4ca2 by -1
# Wrong   a044 > abd2 by -3
# Correct 146f < 6b4e by -14
# Correct 8d45 > 9eb2 by 9
# Correct 6b4e > abd2 by 5
# Correct 146f < 8d45 by -9
# Correct 8d45 > 9eb2 by 9
# Correct 8d45 < abd2 by 0
# Correct 4ca2 > 8ac3 by 6
# Correct 4ca2 > fb4b by 10
# Wrong   8d45 > 4ca2 by -1
# Correct 146f > 9eb2 by 0
# Wrong   146f > 6c5b by -2
# Correct 146f < 4ca2 by -10
# Correct fb4b < 8ac3 by -4
# Correct 4ca2 > 8ac3 by 6
# Correct 146f < 8ac3 by -4
# Correct 8ac3 > fb4b by 4
# Correct 146f > fb4b by 0
# Correct 6c5b > 9eb2 by 2
# Correct 6c5b > fb4b by 2
# Correct 6c5b > 9eb2 by 2
# Correct 9eb2 > fb4b by 0
# Wrong   4c2a > 066e by -4
# Correct 4c2a < 63e1 by -11
# Correct 8d45 < b14b by -9
# Correct b14b > 4ca2 by 8
# Correct 6f62 < 88a6 by -11
# Correct 88a6 > 21de by 12
# Correct 7cc7 > 44bd by 1
# Correct 7cc7 > ad47 by 5
# Correct 6b4e < 3669 by -6
# Correct 3669 > fe28 by 0
# Correct d28c > cb76 by 7
# Correct d28c > abd2 by 11
# Correct a044 < c926 by -13
# Wrong   c926 > eac9 by -1
# Correct 8c43 > 6c5b by 4
# Correct 8c43 < 23a6 by -9
# Correct 8eaf > b56b by 1
# Correct 8eaf > fb4b by 7
# Wrong   b14b > 63e1 by -2
# Wrong   8d45 > 4ca2 by -1
# Correct 8d45 < baa4 by -8
# Correct b14b > baa4 by 1
# Correct 7cc7 > 88a6 by 1
# Wrong   ad47 > 44bd by -4
# Correct ad47 > 8ac3 by 11
# Correct d28c > 3669 by 0
# Correct abd2 < cb76 by -4
# Correct cb76 > 146f by 13
# Wrong   23a6 > c926 by -4
# Correct 8c43 > 6c5b by 4
# Correct 8c43 < 2281 by -14
# Wrong   23a6 > 2281 by -5
# Correct b14b > 8eaf by 11
# Wrong   baa4 > 63e1 by -3
# Wrong   8d45 > 4ca2 by -1
# Correct 8d45 < c938 by -10
# Wrong   baa4 > c938 by -2
# Correct d28c > 7cc7 by 0
# Wrong   cb76 > 3669 by -7
# Correct abd2 > 146f by 9
# Correct abd2 > 9eb2 by 9
# Correct b14b > 23a6 by 3
# Correct baa4 > 8eaf by 10
# Wrong   c938 > 63e1 by -1
# Wrong   8d45 > 4ca2 by -1
# Correct 8d45 < 1953 by -11
# Wrong   c938 > 1953 by -1
# Wrong   b14b > d28c by -2
# Wrong   baa4 < 23a6 by 2
# Correct 2281 > c926 by 1
# Correct 8c43 > 6c5b by 4
# Correct 8c43 < 4c41 by -14
# Correct 2281 > 4c41 by 0
# Wrong   23a6 > d28c by -5
# Correct baa4 < 2281 by -3
# Correct 4c41 > c926 by 1
# Correct 8c43 > 6c5b by 4
# Wrong   8c43 > 066e by -7
# Correct 2281 > d28c by 0
# Wrong   baa4 > 4c41 by -3
# Correct c938 > 8eaf by 12
# Correct 1953 > 63e1 by 0
# Wrong   8d45 > 4ca2 by -1
# Correct 8d45 < 4c2a by 0
# Correct 1953 > 4c2a by 11
# Wrong   baa4 > d28c by -3
# Wrong   c938 > 4c41 by -1
# Correct 1953 > 8eaf by 13
# Correct 4c2a < 63e1 by -11
# Correct 63e1 > 4ca2 by 10
# Wrong   c938 > d28c by -1
# Correct 1953 > 4c41 by 0
# Wrong   63e1 < 8eaf by 13
# Correct fb4b < b56b by -6
# Wrong   b56b > 8d45 by -3
# Correct 1953 > d28c by 0
# Correct 8eaf < 4c41 by -13
# Correct 8c43 < c926 by -13
# Correct a044 < eac9 by -14
# Correct eac9 > 21de by 13
# Correct 4c41 > d28c by 0
# Correct 8eaf < c926 by -12
# Correct 8c43 < eac9 by -14
# Wrong   a044 > 21de by -1
# Correct a044 < 6f62 by -2
# Correct eac9 > 6f62 by 12
# Wrong   c926 > d28c by -1
# Correct 8eaf < eac9 by -13
# Wrong   8c43 > 6f62 by -2
# Correct 066e > 6c5b by 11
# Correct 066e < 44bd by -6
# Correct 8c43 < 44bd by -13
# Correct eac9 > 44bd by 1
# Correct eac9 > d28c by 0
# Wrong   8eaf > 44bd by -12
# Correct 63e1 > b56b by 14
# Wrong   4c2a > 4ca2 by -1
# Correct 4c2a > 8ac3 by 5
# Correct 8eaf < d28c by -13
# Correct cb76 < 7cc7 by -7
# Correct ad47 < 88a6 by -4
# Wrong   88a6 > fe28 by -1
# Correct 8eaf < 7cc7 by -13
# Correct cb76 < 88a6 by -6
# Wrong   ad47 > fe28 by -5
# Correct ad47 > 6b4e by 1
# Correct 8eaf < 88a6 by -12
# Wrong   cb76 > ad47 by -2
# Correct abd2 < 3669 by -11
# Correct 3669 > 146f by 20
# Wrong   8eaf > cb76 by -6
# Correct 63e1 > 44bd by 1
# Correct 4c2a > b56b by 3
# Wrong   8ac3 > 4ca2 by -6
# Correct 8ac3 > 9eb2 by 4
# Wrong   63e1 < cb76 by 7
# Correct 3669 > ad47 by 5
# Correct abd2 > 146f by 9
# Wrong   abd2 < 21de by 2
# Correct 3669 > 21de by 13
# Correct 63e1 < 3669 by 0
# Correct 21de < ad47 by -8
# Correct 6b4e < fe28 by -6
# Correct fe28 > a044 by 14
# Correct 63e1 > ad47 by 5
# Correct 4c2a < 44bd by -10
# Wrong   8c43 > 6f62 by -2
# Correct 066e > 6c5b by 11
# Correct 44bd > ad47 by 4
# Wrong   4c2a < 8c43 by 3
# Wrong   066e < 6f62 by 5
# Correct 6f62 > 6c5b by 6
# Correct 8c43 < ad47 by -9
# Correct 21de < fe28 by -13
# Wrong   6b4e < a044 by 8
# Wrong   a044 > 8d45 by -3
# Correct 8c43 < fe28 by -14
# Correct 21de > a044 by 1
# Correct abd2 > 146f by 9
# Correct abd2 > fb4b by 9
# Correct 8c43 < 21de by -1
# Wrong   abd2 < a044 by 3
# Correct 6b4e > 8d45 by 5
# Correct 6b4e > 4ca2 by 4
# Correct 8c43 > a044 by 0
# Correct 4c2a > 6f62 by 1
# Correct 8ac3 < b56b by -2
# Correct b56b > 9eb2 by 6
# Correct 4c2a > a044 by 3
# Wrong   b56b > 6f62 by -2
# Correct 8ac3 > 9eb2 by 4
# Correct 8ac3 < 8d45 by -5
# Wrong   b56b > 8d45 by -3
# Correct b56b > a044 by 0
# Wrong   8d45 < 6f62 by 1
# Correct 066e > 6c5b by 11
# Correct 066e > 4ca2 by 3
# Correct 6f62 > a044 by 2
# Correct 8d45 < 066e by -4
# Correct 4ca2 > 6c5b by 8
# Correct 4ca2 > 146f by 10
# Correct 066e > a044 by 7
# Wrong   8d45 > 4ca2 by -1
# Correct 8ac3 > 9eb2 by 4
# Correct 8ac3 > fb4b by 4
# Wrong   8d45 < a044 by 3
# Wrong   abd2 > 6b4e by -5
# Correct abd2 > 6c5b by 7
# Correct 8d45 < abd2 by 0
# Correct 6c5b < 6b4e by -12
# Correct 6b4e > 146f by 14
# Correct 8d45 < 6b4e by -5
# Correct 6c5b > 146f by 2
# Correct 6c5b > 9eb2 by 2
# Correct 8d45 > 6c5b by 7
# Wrong   8ac3 > 4ca2 by -6
# Correct 8ac3 > fb4b by 4
# Correct 8ac3 > 6c5b by 2
# Correct fb4b < 4ca2 by -10
# Correct 4ca2 > 146f by 10
# Correct 4ca2 > 6c5b by 8
# Correct fb4b > 146f by 0
# Correct fb4b < 9eb2 by 0
# Correct 4ca2 > 9eb2 by 10
# Correct 9eb2 < 6c5b by -2
# Correct 6c5b > 146f by 2
# Correct 9eb2 > 146f by 0
# Correct 9eb2 > fb4b by 0
# Correct fb4b > 146f by 0
# Correct 146f < 44bd by -19
# Correct 44bd > cb76 by 6
# Correct 7cc7 > 8ac3 by 16
# Correct 7cc7 > 8d45 by 11
# Correct 2281 > fe28 by 0
# Correct 2281 > 4c2a by 11
# Wrong   21de > abd2 by -2
# Correct 21de < baa4 by -10
# Correct c926 > 9eb2 by 19
# Wrong   c926 > 63e1 by -1
# Correct 1953 > eac9 by 0
# Correct 1953 > 4ca2 by 10
# Correct 6c5b < 8c43 by -4
# Wrong   8c43 > 6f62 by -2
# ...
# Correct 63e1 > ad47 by 5
# Correct 63e1 > 066e by 7
# Correct 6f62 < 23a6 by -7
# Correct b56b < 63e1 by -14
# Correct 066e < ad47 by -2
# Correct ad47 > 146f by 15
# Correct 6f62 < 63e1 by -12
# Correct b56b < ad47 by -9
# Correct 066e > 146f by 13
# Correct 066e > 6c5b by 11
# Wrong   6f62 > ad47 by -7
# Correct 6b4e > 21de by 7
# Wrong   a044 > 4c2a by -3
# Wrong   4ca2 < 8ac3 by 6
# Wrong   8ac3 > 8d45 by -5
# Correct 6b4e < ad47 by -1
# Wrong   b56b > 066e by -7
# Correct 9eb2 > fb4b by 0
# Wrong   9eb2 > 8d45 by -9
# Correct 6b4e > b56b by 8
# Wrong   a044 > 21de by -1
# Wrong   8ac3 > 4c2a by -5
# Wrong   8ac3 > 4ca2 by -6
# Correct a044 < b56b by 0
# Wrong   9eb2 > 066e by -13
# Correct 8d45 > fb4b by 9
# Correct 8d45 > 146f by 9
# Correct a044 > 9eb2 by 6
# Wrong   8ac3 > 21de by -3
# Wrong   4ca2 < 4c2a by 1
# Correct 4c2a > 6c5b by 7
# Correct 8ac3 > 9eb2 by 4
# Correct 4c2a > 21de by 2
# Correct 4ca2 > 6c5b by 8
# Correct 4ca2 > fb4b by 10
# Correct 4c2a > 9eb2 by 9
# Wrong   4ca2 < 21de by 3
# Wrong   8c43 > abd2 by -3
# Correct 8c43 > 146f by 6
# Correct 21de > 9eb2 by 7
# Wrong   4ca2 < 8c43 by 4
# Correct 146f < abd2 by -9
# Wrong   8c43 > abd2 by -3
# Correct 8c43 > 9eb2 by 6
# Correct 4ca2 > abd2 by 1
# Wrong   fb4b > 6c5b by -2
# Correct fb4b > 146f by 0
# Correct 4ca2 > 9eb2 by 10
# Wrong   fb4b > abd2 by -9
# Correct 146f < 6c5b by -2
# Wrong   fb4b > 6c5b by -2
# Correct fb4b > 9eb2 by 0
# Correct 6c5b < abd2 by -7
# Correct abd2 > 146f by 9
# Correct abd2 > 9eb2 by 9
# Correct 6c5b > 146f by 2
# Correct 6c5b < 066e by -11
# Wrong   abd2 > 066e by -4
# Correct 066e > 9eb2 by 13
# Correct 6c5b > 146f by 2
# Wrong   6c5b > 8d45 by -7
# Correct 6c5b > 9eb2 by 2
# Correct 8d45 > 146f by 9
# Correct 8d45 > 9eb2 by 9
# Correct 8d45 > 146f by 9
# Correct 146f > 9eb2 by 0
# Wrong   c938 > 3669 by -1
# Correct c938 > baa4 by 2
# Correct 146f < 2281 by -20
# Correct 2281 > 63e1 by 0
# Correct 6f62 < eac9 by -12
# Correct eac9 > 8d45 by 11
# Correct 44bd > 8eaf by 12
# Correct 44bd < 88a6 by 0
# Correct 8ac3 < 23a6 by -11
# Correct 23a6 > 6c5b by 13
# Correct b56b < d28c by -14
# Correct d28c > 6b4e by 6
# Wrong   1953 < c926 by 1
# Correct c926 > ad47 by 4
# Correct 066e > 4ca2 by 3
# Correct 066e < b14b by -5
# Correct fb4b < cb76 by -13
# Correct cb76 > 9eb2 by 13
# Correct 2281 > c938 by 1
# Correct 146f < 63e1 by -20
# Correct 63e1 > 8c43 by 14
# Correct 88a6 < eac9 by -1
# Wrong   6f62 > 8d45 by -1
# Correct 6f62 < fe28 by -12
# Correct eac9 > fe28 by 0
# Correct d28c > 23a6 by 5
# Wrong   b56b > 6b4e by -8
# Wrong   b56b > 4c2a by -3
# Wrong   b14b > c926 by -1
# Correct 066e > 4ca2 by 3
# Correct 066e > abd2 by 4
# Correct 2281 > cb76 by 7
# Wrong   63e1 < c938 by 1
# Wrong   baa4 > 3669 by -3
# Correct baa4 < 7cc7 by -3
# Wrong   c938 > 7cc7 by -1
# Correct d28c > eac9 by 0
# Correct b56b < 23a6 by -9
# Correct 8ac3 > 6c5b by 2
# Wrong   8ac3 > a044 by -2
# Correct 2281 > b14b by 2
# Correct c938 > cb76 by 6
# Correct 63e1 < 7cc7 by 0
# Wrong   baa4 > 3669 by -3
# Wrong   baa4 > 4c41 by -3
# Correct 2281 < d28c by 0
# Wrong   23a6 > eac9 by -5
# Correct b56b > 8ac3 by 2
# Wrong   4c2a > 6b4e by -5
# Correct 4c2a > 21de by 2
# Correct 2281 > 23a6 by 5
# Correct c938 > b14b by 1
# Correct 7cc7 > cb76 by 7
# Wrong   63e1 < baa4 by 3
# Correct 4c41 < 3669 by 0
# Wrong   baa4 > 3669 by -3
# Correct c938 > 23a6 by 4
# Correct 7cc7 > b14b by 2
# Correct baa4 > cb76 by 4
# Correct 63e1 < 3669 by 0
# Correct 3669 > 4c41 by 0
# Correct 7cc7 > 23a6 by 5
# Wrong   baa4 > b14b by -1
# Correct 3669 > cb76 by 7
# Correct 63e1 < 4c41 by 0
# Correct 4c41 > 8c43 by 14
# Wrong   baa4 < 23a6 by 2
# Correct b56b < eac9 by -14
# Wrong   88a6 > fe28 by -1
# Correct 44bd > 8eaf by 12
# Correct 44bd > 146f by 19
# Correct baa4 < eac9 by -3
# Correct b56b < 88a6 by -13
# Wrong   44bd > fe28 by -1
# Correct 146f < 8eaf by -7
# Wrong   8eaf > 8d45 by -2
# Wrong   baa4 > 88a6 by -2
# Correct 3669 > b14b by 2
# Correct 4c41 > cb76 by 7
# Correct 63e1 > 8c43 by 14
# Correct 63e1 > 6f62 by 12
# Correct 3669 > 88a6 by 1
# Correct 4c41 > b14b by 2
# Correct 63e1 > cb76 by 7
# Correct 6f62 > 8c43 by 2
# Wrong   6f62 > 8d45 by -1
# Correct 4c41 > 88a6 by 1
# Wrong   63e1 < b14b by 2
# Correct 066e < c926 by -6
# Correct 1953 > ad47 by 5
# Correct 1953 > 146f by 20
# Wrong   b14b > 88a6 by -1
# Wrong   63e1 < c926 by 1
# Correct 066e < 1953 by -7
# Correct 146f < ad47 by -15
# Correct ad47 > 6c5b by 13
# Correct c926 > 88a6 by 0
# Correct 63e1 > 1953 by 0
# Correct 6f62 < cb76 by -5
# Correct fb4b > 9eb2 by 0
# Correct fb4b < a044 by -6
# Correct cb76 > a044 by 7
# Correct 63e1 > 88a6 by 1
# Wrong   cb76 > 1953 by -7
# Correct 6f62 > a044 by 2
# Wrong   8d45 < 8c43 by 3
# Wrong   8c43 > 6b4e by -8
# Wrong   cb76 > 88a6 by -6
# Correct 6f62 < 1953 by -12
# Correct 066e < ad47 by -2
# Wrong   146f > 6c5b by -2
# Correct 146f < 21de by -7
# Correct ad47 > 21de by 8
# Correct 1953 > 88a6 by 1
# Wrong   6f62 > ad47 by -7
# Correct 8c43 > a044 by 0
# Correct 8d45 < 6b4e by -5
# Correct 6b4e > 6c5b by 12
# Correct 6f62 < 88a6 by -11
# Correct b56b < 44bd by -13
# Wrong   8eaf > fe28 by -13
# Correct 8eaf > 146f by 7
# Correct 6f62 < 44bd by -11
# Correct b56b < 8eaf by -1
# Correct 146f < fe28 by -20
# Correct fe28 > 4ca2 by 10
# Wrong   6f62 < 8eaf by 1
# Correct b56b < fe28 by -14
# Correct 146f < 4ca2 by -10
# Wrong   4ca2 < abd2 by 1
# Correct fe28 > abd2 by 11
# Correct 6f62 < fe28 by -12
# Wrong   b56b > abd2 by -3
# Correct 4c2a > 8ac3 by 5
# Correct 4c2a > 9eb2 by 9
# Correct 6f62 > b56b by 2
# Correct 8c43 < ad47 by -9
# Correct 066e > 21de by 6
# Correct 066e > fb4b by 13
# Correct ad47 > b56b by 9
# Correct 8c43 < 066e by -7
# Correct fb4b < 21de by -7
# Correct 21de > 6c5b by 5
# Wrong   066e < b56b by 7
# Correct 4c2a > abd2 by 0
# Correct 9eb2 < 8ac3 by -4
# Wrong   8ac3 > 8d45 by -5
# Correct 066e > 4c2a by 4
# Correct 8c43 < 21de by -1
# Wrong   fb4b > 6c5b by -2
# Wrong   fb4b > 4ca2 by -10
# Wrong   21de > 4c2a by -2
# Correct 8c43 > fb4b by 6
# Correct 6b4e > a044 by 8
# Correct 6b4e > 146f by 14
# Wrong   8c43 > 4c2a by -3
# Correct 6b4e > fb4b by 14
# Correct 146f < a044 by -6
# Wrong   a044 > 8d45 by -3
# Correct 6b4e > 4c2a by 5
# Correct a044 > fb4b by 6
# Correct 146f < 8d45 by -9
# Correct 8d45 > 9eb2 by 9
# Wrong   a044 > 4c2a by -3
# Correct 8d45 > fb4b by 9
# Correct 146f > 9eb2 by 0
# Wrong   146f > 6c5b by -2
# Correct 8d45 < 4c2a by 0
# Wrong   8ac3 > abd2 by -5
# Wrong   8ac3 > 4ca2 by -6
# Wrong   8d45 < 8ac3 by 5
# Wrong   4ca2 < abd2 by 1
# Correct abd2 > 9eb2 by 9
# Correct 8d45 > abd2 by 0
# Correct 146f > fb4b by 0
# Wrong   146f > 6c5b by -2
# Correct 146f < abd2 by -9
# Correct 4ca2 > 9eb2 by 10
# Correct 146f < 4ca2 by -10
# Correct 4ca2 > 9eb2 by 10
# Correct 146f > 9eb2 by 0
# Correct 6c5b > fb4b by 2
# Correct 6c5b > 9eb2 by 2
# Correct 6c5b > fb4b by 2
# Correct fb4b > 9eb2 by 0
# Correct 8c43 < 23a6 by -9
# Correct 8c43 < 23a6 by -9
# Wrong   23a6 > 7cc7 by -5
# Wrong   23a6 > 7cc7 by -5
# Correct 8ac3 < b56b by -2
# Correct 8ac3 < b56b by -2
# Correct b56b > 9eb2 by 6
# Correct b56b > 9eb2 by 6
# Correct 44bd > fb4b by 19
# Correct 44bd > fb4b by 19
# Correct 44bd > 8eaf by 12
# Correct 44bd > 8eaf by 12
# Correct abd2 > 146f by 9
# Correct abd2 > 146f by 9
# Correct abd2 < c938 by -10
# Correct abd2 < c938 by -10
# Wrong   c926 < baa4 by 2
# Wrong   c926 < baa4 by 2
# Correct baa4 > 8d45 by 8
# Correct baa4 > 8d45 by 8
# Correct 3669 > eac9 by 0
# Correct 3669 > eac9 by 0
# Wrong   3669 < b14b by 2
# Wrong   3669 < b14b by 2
# Wrong   6f62 > fe28 by -12
# Wrong   6f62 > fe28 by -12
# Correct 6f62 < 1953 by -12
# Correct 6f62 < 1953 by -12
# Correct 4c41 > 6b4e by 6
# Correct 4c41 > 6b4e by 6
# Correct 4c41 > a044 by 14
# Correct 4c41 > a044 by 14
# Correct 2281 > 4c2a by 11
# Correct 2281 > 4c2a by 11
# Correct 2281 > 066e by 7
# Correct 2281 > 066e by 7
# Correct b56b < 23a6 by -9
# Correct b56b < 23a6 by -9
# Correct 8c43 < 7cc7 by -14
# Correct 8c43 < 7cc7 by -14
# Correct 7cc7 > 21de by 13
# Correct 7cc7 > 21de by 13
# Correct c938 > 44bd by 0
# Correct c938 > 44bd by 0
# Correct abd2 > 146f by 9
# Correct abd2 > 146f by 9
# Correct abd2 > 6c5b by 7
# Correct abd2 > 6c5b by 7
# Correct b14b > baa4 by 1
# Correct b14b > baa4 by 1
# Correct 3669 > eac9 by 0
# Correct 3669 > eac9 by 0
# Correct 3669 > 63e1 by 0
# Correct 3669 > 63e1 by 0
# Correct 4c41 > 1953 by 0
# Correct 4c41 > 1953 by 0
# Wrong   a044 > 6b4e by -8
# Wrong   a044 > 6b4e by -8
# Correct a044 < d28c by -14
# Correct a044 < d28c by -14
# Correct 4c41 > d28c by 0
# Correct 4c41 > d28c by 0
# Wrong   23a6 > 2281 by -5
# Wrong   23a6 > 2281 by -5
# Correct b56b < 7cc7 by -14
# Correct b56b < 7cc7 by -14
# Wrong   8c43 > 21de by -1
# Wrong   8c43 > 21de by -1
# Correct 8c43 < cb76 by -7
# Correct 8c43 < cb76 by -7
# Correct 7cc7 > cb76 by 7
# Correct 7cc7 > cb76 by 7
# Wrong   b14b > c938 by -1
# Wrong   b14b > c938 by -1
# Correct 3669 > baa4 by 3
# Correct 3669 > baa4 by 3
# Correct 63e1 < eac9 by 0
# Correct 63e1 < eac9 by 0
# Correct eac9 > ad47 by 5
# Correct eac9 > ad47 by 5
# Wrong   23a6 > 4c41 by -5
# Wrong   23a6 > 4c41 by -5
# Correct 7cc7 > 2281 by 0
# Correct 7cc7 > 2281 by 0
# Correct b56b < cb76 by -7
# Correct b56b < cb76 by -7
# Wrong   8c43 > 21de by -1
# Wrong   8c43 > 21de by -1
# Correct 8c43 < 88a6 by -13
# Correct 8c43 < 88a6 by -13
# Correct cb76 < 88a6 by -6
# Correct cb76 < 88a6 by -6
# Correct 7cc7 > 88a6 by 1
# Correct 7cc7 > 88a6 by 1
# Wrong   23a6 > b14b by -3
# Wrong   23a6 > b14b by -3
# Correct 7cc7 > 4c41 by 0
# Correct 7cc7 > 4c41 by 0
# Correct 88a6 < 2281 by -1
# Correct 88a6 < 2281 by -1
# Correct 066e > 4c2a by 4
# Correct 066e > 4c2a by 4
# Correct 066e > 4ca2 by 3
# Correct 066e > 4ca2 by 3
# Correct 7cc7 > b14b by 2
# Correct 7cc7 > b14b by 2
# Correct 2281 > 4c41 by 0
# Correct 2281 > 4c41 by 0
# Correct 88a6 > 066e by 6
# Correct 88a6 > 066e by 6
# Correct b56b < cb76 by -7
# Correct b56b < cb76 by -7
# Wrong   8c43 > 21de by -1
# Wrong   8c43 > 21de by -1
# Correct 2281 > b14b by 2
# Correct 2281 > b14b by 2
# Wrong   88a6 > 4c41 by -1
# Wrong   88a6 > 4c41 by -1
# Correct cb76 > 066e by 0
# Correct cb76 > 066e by 0
# Correct b56b > 8c43 by 0
# Correct b56b > 8c43 by 0
# Correct 8ac3 > 9eb2 by 4
# Correct 8ac3 > 9eb2 by 4
# Correct 8ac3 < 21de by -3
# Correct 8ac3 < 21de by -3
# Wrong   b56b > 21de by -1
# Wrong   b56b > 21de by -1
# Correct 88a6 > b14b by 1
# Correct 88a6 > b14b by 1
# Wrong   cb76 > 4c41 by -7
# Wrong   cb76 > 4c41 by -7
# Wrong   b56b > 066e by -7
# Wrong   b56b > 066e by -7
# Wrong   21de < 8c43 by 1
# Wrong   21de < 8c43 by 1
# Correct 8c43 > 9eb2 by 6
# Correct 8c43 > 9eb2 by 6
# Correct cb76 < b14b by -5
# Correct cb76 < b14b by -5
# Correct 3669 > c938 by 1
# Correct 3669 > c938 by 1
# Correct eac9 > baa4 by 3
# Correct eac9 > baa4 by 3
# Correct 63e1 > ad47 by 5
# Correct 63e1 > ad47 by 5
# Correct 63e1 > 8ac3 by 16
# Correct 63e1 > 8ac3 by 16
# Wrong   cb76 > 3669 by -7
# Wrong   cb76 > 3669 by -7
# Correct b56b < 4c41 by -14
# Correct b56b < 4c41 by -14
# Correct d28c > 1953 by 0
# Correct d28c > 1953 by 0
# Wrong   a044 > 6b4e by -8
# Wrong   a044 > 6b4e by -8
# Correct a044 > fb4b by 6
# Correct a044 > fb4b by 6
# Correct 4c41 > 3669 by 0
# Correct 4c41 > 3669 by 0
# Correct b56b < d28c by -14
# Correct b56b < d28c by -14
# Correct a044 < 1953 by -14
# Correct a044 < 1953 by -14
# Wrong   6f62 > fe28 by -12
# Wrong   6f62 > fe28 by -12
# Wrong   6f62 < 8eaf by 1
# Wrong   6f62 < 8eaf by 1
# Correct 1953 > 8eaf by 13
# Correct 1953 > 8eaf by 13
# Correct d28c > 3669 by 0
# Correct d28c > 3669 by 0
# Correct b56b < 1953 by -14
# Correct b56b < 1953 by -14
# Correct a044 < 8eaf by -1
# Correct a044 < 8eaf by -1
# Wrong   6f62 > fe28 by -12
# Wrong   6f62 > fe28 by -12
# Correct 6f62 > 146f by 8
# Correct 6f62 > 146f by 8
# Correct 1953 > 3669 by 0
# Correct 1953 > 3669 by 0
# Correct b56b < 8eaf by -1
# Correct b56b < 8eaf by -1
# Correct a044 < 6f62 by -2
# Correct a044 < 6f62 by -2
# Correct 146f < fe28 by -20
# Correct 146f < fe28 by -20
# Correct fe28 > 6c5b by 18
# Correct fe28 > 6c5b by 18
# Correct 8eaf < 3669 by -13
# Correct 8eaf < 3669 by -13
# Correct eac9 > c938 by 1
# Correct eac9 > c938 by 1
# Correct 63e1 > baa4 by 3
# Correct 63e1 > baa4 by 3
# Correct 8ac3 < ad47 by -11
# Correct 8ac3 < ad47 by -11
# Correct ad47 > 8d45 by 6
# Correct ad47 > 8d45 by 6
# Correct 8eaf < eac9 by -13
# Correct 8eaf < eac9 by -13
# Wrong   63e1 < c938 by 1
# Wrong   63e1 < c938 by 1
# Correct abd2 < 44bd by -10
# Correct abd2 < 44bd by -10
# Correct 44bd > c926 by 0
# Correct 44bd > c926 by 0
# Wrong   8eaf > c938 by -12
# Wrong   8eaf > c938 by -12
# Wrong   b56b > 6f62 by -2
# Wrong   b56b > 6f62 by -2
# Wrong   8c43 > 066e by -7
# Wrong   8c43 > 066e by -7
# Correct 21de > 9eb2 by 7
# Correct 21de > 9eb2 by 7
# Wrong   21de > 8d45 by -2
# Wrong   21de > 8d45 by -2
# Correct b56b < c938 by -13
# Correct b56b < c938 by -13
# Correct 63e1 > 44bd by 1
# Correct 63e1 > 44bd by 1
# Correct ad47 < baa4 by -2
# Correct ad47 < baa4 by -2
# Correct baa4 > 8ac3 by 13
# Correct baa4 > 8ac3 by 13
# Correct b56b < 63e1 by -14
# Correct b56b < 63e1 by -14
# Wrong   baa4 > 44bd by -2
# Wrong   baa4 > 44bd by -2
# Correct ad47 > 8ac3 by 11
# Correct ad47 > 8ac3 by 11
# Correct ad47 > 6c5b by 13
# Correct ad47 > 6c5b by 13
# Correct b56b < baa4 by -11
# Correct b56b < baa4 by -11
# Wrong   ad47 > 44bd by -4
# Wrong   ad47 > 44bd by -4
# Correct 6c5b < 8ac3 by -2
# Correct 6c5b < 8ac3 by -2
# Correct 8ac3 > 146f by 4
# Correct 8ac3 > 146f by 4
# Correct b56b < ad47 by -9
# Correct b56b < ad47 by -9
# Correct 8ac3 < 44bd by -15
# Correct 8ac3 < 44bd by -15
# Correct abd2 < c926 by -10
# Correct abd2 < c926 by -10
# Correct c926 > 6b4e by 5
# Correct c926 > 6b4e by 5
# Correct b56b < 44bd by -13
# Correct b56b < 44bd by -13
# Correct 8ac3 < c926 by -15
# Correct 8ac3 < c926 by -15
# Wrong   abd2 > 6b4e by -5
# Wrong   abd2 > 6b4e by -5
# Correct abd2 > fb4b by 9
# Correct abd2 > fb4b by 9
# Correct b56b < c926 by -13
# Correct b56b < c926 by -13
# Wrong   8ac3 > abd2 by -5
# Wrong   8ac3 > abd2 by -5
# Correct 6c5b > 146f by 2
# Correct 6c5b > 146f by 2
# Correct 6c5b < 4c2a by -7
# Correct 6c5b < 4c2a by -7
# Wrong   8ac3 > 4c2a by -5
# Wrong   8ac3 > 4c2a by -5
# Correct b56b > 8ac3 by 2
# Correct b56b > 8ac3 by 2
# Wrong   8c43 > 6f62 by -2
# Wrong   8c43 > 6f62 by -2
# Wrong   21de > 066e by -6
# Wrong   21de > 066e by -6
# Correct 8d45 > 9eb2 by 9
# Correct 8d45 > 9eb2 by 9
# Wrong   8d45 > 4ca2 by -1
# Wrong   8d45 > 4ca2 by -1
# Correct 8c43 > 8ac3 by 2
# Correct 8c43 > 8ac3 by 2
# Correct 21de < 6f62 by -1
# Correct 21de < 6f62 by -1
# Correct a044 < fe28 by -14
# Correct a044 < fe28 by -14
# Correct fe28 > 9eb2 by 20
# Correct fe28 > 9eb2 by 20
# Correct 6f62 > 8ac3 by 4
# Correct 6f62 > 8ac3 by 4
# Correct 21de < fe28 by -13
# Correct 21de < fe28 by -13
# Correct a044 > 9eb2 by 6
# Correct a044 > 9eb2 by 6
# Wrong   a044 > 4ca2 by -4
# Wrong   a044 > 4ca2 by -4
# Correct fe28 > 8ac3 by 16
# Correct fe28 > 8ac3 by 16
# Correct 21de > a044 by 1
# Correct 21de > a044 by 1
# Correct 8d45 < 066e by -4
# Correct 8d45 < 066e by -4
# Wrong   066e > 6b4e by -1
# Wrong   066e > 6b4e by -1
# Correct 21de > 8ac3 by 3
# Correct 21de > 8ac3 by 3
# Correct 066e > a044 by 7
# Correct 066e > a044 by 7
# Correct 8d45 < 6b4e by -5
# Correct 8d45 < 6b4e by -5
# Correct 6b4e > fb4b by 14
# Correct 6b4e > fb4b by 14
# Correct 066e > 8ac3 by 9
# Correct 066e > 8ac3 by 9
# Wrong   6b4e < a044 by 8
# Wrong   6b4e < a044 by 8
# Correct 4ca2 > 9eb2 by 10
# Correct 4ca2 > 9eb2 by 10
# Correct 4ca2 > 146f by 10
# Correct 4ca2 > 146f by 10
# Correct a044 > 8ac3 by 2
# Correct a044 > 8ac3 by 2
# Correct 6b4e > 4ca2 by 4
# Correct 6b4e > 4ca2 by 4
# Correct 8d45 > fb4b by 9
# Correct 8d45 > fb4b by 9
# Correct 8d45 > 6c5b by 7
# Correct 8d45 > 6c5b by 7
# Correct 6b4e > 8ac3 by 10
# Correct 6b4e > 8ac3 by 10
# Wrong   8d45 > 4ca2 by -1
# Wrong   8d45 > 4ca2 by -1
# Correct 6c5b > fb4b by 2
# Correct 6c5b > fb4b by 2
# Correct 6c5b > 9eb2 by 2
# Correct 6c5b > 9eb2 by 2
# Correct 8d45 > 8ac3 by 5
# Correct 8d45 > 8ac3 by 5
# Correct 6c5b < 4ca2 by -8
# Correct 6c5b < 4ca2 by -8
# Correct 4ca2 > 146f by 10
# Correct 4ca2 > 146f by 10
# Correct 4ca2 > 8ac3 by 6
# Correct 4ca2 > 8ac3 by 6
# Correct 6c5b > 146f by 2
# Correct 6c5b > 146f by 2
# Correct 9eb2 > fb4b by 0
# Correct 9eb2 > fb4b by 0
# Correct 6c5b < 8ac3 by -2
# Correct 6c5b < 8ac3 by -2
# Correct 4c2a > abd2 by 0
# Correct 4c2a > abd2 by 0
# Correct 4c2a > fb4b by 9
# Correct 4c2a > fb4b by 9
# Correct 6c5b < 4c2a by -7
# Correct 6c5b < 4c2a by -7
# Correct fb4b < abd2 by -9
# Correct fb4b < abd2 by -9
# Correct 4c2a > abd2 by 0
# Correct 4c2a > abd2 by 0
# Correct 6c5b < abd2 by -7
# Correct 6c5b < abd2 by -7
# Correct abd2 > fb4b by 9
# Correct abd2 > fb4b by 9
# Correct 6c5b > fb4b by 2
# Correct 6c5b > fb4b by 2
# Correct 9eb2 > 146f by 0
# Correct 9eb2 > 146f by 0
# Correct 9eb2 > fb4b by 0
# Correct 9eb2 > fb4b by 0
# Correct 9eb2 > 146f by 0
# Correct 9eb2 > 146f by 0
# Correct 146f > fb4b by 0
# Correct 146f > fb4b by 0

# %%
for l in sorted(problematic_notebooks, key=lambda x: problematic_notebooks[x], reverse=True):
    print(f'{l}: {problematic_notebooks[l]}')
# Out:
# 8d45: 83
# 6f62: 75
# 4ca2: 73
# 6b4e: 71
# abd2: 71
# 8eaf: 68
# 21de: 65
# baa4: 64
# 8c43: 62
# 1953: 57
# a044: 57
# b56b: 56
# 066e: 56
# 8ac3: 53
# cb76: 51
# b14b: 50
# 23a6: 48
# 4c2a: 45
# c938: 44
# 63e1: 42
# c926: 41
# 6c5b: 40
# 88a6: 39
# 44bd: 39
# fe28: 35
# ad47: 33
# 3669: 31
# fb4b: 23
# 4c41: 20
# d28c: 18
# 146f: 17
# eac9: 11
# 2281: 10
# 9eb2: 9
# 7cc7: 7

# %%
# ↑ Zahl heißt das Notebook wird häufiger besser bewertet, als es eigentlich ist
# ↓ Zahl heißt das Notebook wird häufiger schlechter bewertet, als es eigentlich ist
print(f'Notb:   Score   Wrg.Comparisons   Total Points')
for l in sorted(point_diffs, key=lambda x: point_diffs[x], reverse=True):
    print(f'{l}:   {point_diffs[l]:5d}   {problematic_notebooks[l]:15d}   {expert_ranking.loc[expert_ranking["id"] == l, "total_points"].values[0]:10d}')
# Out:
# Notb:   Score   Wrg.Comparisons   Total Points
# 8eaf:     558                68            7
# 8ac3:     290                53            4
# a044:     231                57            6
# 8c43:     216                62            6
# 23a6:     198                48           15
# b56b:     192                56            6
# cb76:     185                51           13
# 6f62:     177                75            8
# 21de:     115                65            7
# fb4b:      91                23            0
# baa4:      90                64           17
# 9eb2:      70                 9            0
# b14b:      48                50           18
# 146f:      34                17            0
# 7cc7:     -16                 7           20
# ad47:     -20                33           15
# 88a6:     -23                39           19
# c926:     -29                41           19
# 2281:     -40                10           20
# eac9:     -46                11           20
# 4c2a:     -48                45            9
# d28c:     -51                18           20
# 6c5b:     -53                40            2
# c938:     -57                44           19
# 4c41:     -60                20           20
# 3669:     -71                31           20
# abd2:    -100                71            9
# 44bd:    -120                39           19
# 63e1:    -185                42           20
# 1953:    -199                57           20
# fe28:    -205                35           20
# 8d45:    -207                83            9
# 4ca2:    -217                73           10
# 066e:    -301                56           13
# 6b4e:    -447                71           14

# %%
# plot score vs. total points
import matplotlib.pyplot as plt
import numpy as np

#x = [point_diffs[l] for l in point_diffs]
#y = [problematic_notebooks[l] for l in point_diffs]

x = [expert_ranking.loc[expert_ranking["id"] == l, "total_points"].values[0] for l in point_diffs]
y = [point_diffs[l] for l in point_diffs]

fig, ax = plt.subplots()
ax.scatter(x, y)

for i, txt in enumerate(point_diffs):
    ax.annotate(txt, (x[i], y[i]))

plt.show()
